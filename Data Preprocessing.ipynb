# %%
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger.zip.
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger_ru.zip.
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Unzipping grammars/basque_grammars.zip.
#        | Downloading package bcp47 to /root/nltk_data...
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package bllip_wsj_no_aux to /root/nltk_data...
#        |   Unzipping models/bllip_wsj_no_aux.zip.
#        | Downloading package book_grammars to /root/nltk_data...
#        |   Unzipping grammars/book_grammars.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
#        | Downloading package cess_esp to /root/nltk_data...
#        |   Unzipping corpora/cess_esp.zip.
#        | Downloading package chat80 to /root/nltk_data...
#        |   Unzipping corpora/chat80.zip.
#        | Downloading package city_database to /root/nltk_data...
#        |   Unzipping corpora/city_database.zip.
#        | Downloading package cmudict to /root/nltk_data...
#        |   Unzipping corpora/cmudict.zip.
#        | Downloading package comparative_sentences to
#        |     /root/nltk_data...
#        |   Unzipping corpora/comparative_sentences.zip.
#        | Downloading package comtrans to /root/nltk_data...
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Unzipping corpora/conll2000.zip.
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Unzipping corpora/conll2002.zip.
#        | Downloading package conll2007 to /root/nltk_data...
#        | Downloading package crubadan to /root/nltk_data...
#        |   Unzipping corpora/crubadan.zip.
#        | Downloading package dependency_treebank to /root/nltk_data...
#        |   Unzipping corpora/dependency_treebank.zip.
#        | Downloading package dolch to /root/nltk_data...
#        |   Unzipping corpora/dolch.zip.
#        | Downloading package europarl_raw to /root/nltk_data...
#        |   Unzipping corpora/europarl_raw.zip.
#        | Downloading package extended_omw to /root/nltk_data...
#        | Downloading package floresta to /root/nltk_data...
#        |   Unzipping corpora/floresta.zip.
#        | Downloading package framenet_v15 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v15.zip.
#        | Downloading package framenet_v17 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v17.zip.
#        | Downloading package gazetteers to /root/nltk_data...
#        |   Unzipping corpora/gazetteers.zip.
#        | Downloading package genesis to /root/nltk_data...
#        |   Unzipping corpora/genesis.zip.
#        | Downloading package gutenberg to /root/nltk_data...
#        |   Unzipping corpora/gutenberg.zip.
#        | Downloading package ieer to /root/nltk_data...
#        |   Unzipping corpora/ieer.zip.
#        | Downloading package inaugural to /root/nltk_data...
#        |   Unzipping corpora/inaugural.zip.
#        | Downloading package indian to /root/nltk_data...
#        |   Unzipping corpora/indian.zip.
#        | Downloading package jeita to /root/nltk_data...
#        | Downloading package kimmo to /root/nltk_data...
#        |   Unzipping corpora/kimmo.zip.
#        | Downloading package knbc to /root/nltk_data...
#        | Downloading package large_grammars to /root/nltk_data...
#        |   Unzipping grammars/large_grammars.zip.
#        | Downloading package lin_thesaurus to /root/nltk_data...
#        |   Unzipping corpora/lin_thesaurus.zip.
#        | Downloading package mac_morpho to /root/nltk_data...
#        |   Unzipping corpora/mac_morpho.zip.
#        | Downloading package machado to /root/nltk_data...
#        | Downloading package masc_tagged to /root/nltk_data...
#        | Downloading package maxent_ne_chunker to /root/nltk_data...
#        |   Unzipping chunkers/maxent_ne_chunker.zip.
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
#        | Downloading package moses_sample to /root/nltk_data...
#        |   Unzipping models/moses_sample.zip.
#        | Downloading package movie_reviews to /root/nltk_data...
#        |   Unzipping corpora/movie_reviews.zip.
#        | Downloading package mte_teip5 to /root/nltk_data...
#        |   Unzipping corpora/mte_teip5.zip.
#        | Downloading package mwa_ppdb to /root/nltk_data...
#        |   Unzipping misc/mwa_ppdb.zip.
#        | Downloading package names to /root/nltk_data...
#        |   Unzipping corpora/names.zip.
#        | Downloading package nombank.1.0 to /root/nltk_data...
#        | Downloading package nonbreaking_prefixes to
#        |     /root/nltk_data...
#        |   Unzipping corpora/nonbreaking_prefixes.zip.
#        | Downloading package nps_chat to /root/nltk_data...
#        |   Unzipping corpora/nps_chat.zip.
#        | Downloading package omw to /root/nltk_data...
#        | Downloading package omw-1.4 to /root/nltk_data...
#        |   Package omw-1.4 is already up-to-date!
#        | Downloading package opinion_lexicon to /root/nltk_data...
#        |   Unzipping corpora/opinion_lexicon.zip.
#        | Downloading package panlex_swadesh to /root/nltk_data...
#        | Downloading package paradigms to /root/nltk_data...
#        |   Unzipping corpora/paradigms.zip.
#        | Downloading package pe08 to /root/nltk_data...
#        |   Unzipping corpora/pe08.zip.
#        | Downloading package perluniprops to /root/nltk_data...
#        |   Unzipping misc/perluniprops.zip.
#        | Downloading package pil to /root/nltk_data...
#        |   Unzipping corpora/pil.zip.
#        | Downloading package pl196x to /root/nltk_data...
#        |   Unzipping corpora/pl196x.zip.
#        | Downloading package porter_test to /root/nltk_data...
#        |   Unzipping stemmers/porter_test.zip.
#        | Downloading package ppattach to /root/nltk_data...
#        |   Unzipping corpora/ppattach.zip.
#        | Downloading package problem_reports to /root/nltk_data...
#        |   Unzipping corpora/problem_reports.zip.
#        | Downloading package product_reviews_1 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_1.zip.
#        | Downloading package product_reviews_2 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_2.zip.
#        | Downloading package propbank to /root/nltk_data...
#        | Downloading package pros_cons to /root/nltk_data...
#        |   Unzipping corpora/pros_cons.zip.
#        | Downloading package ptb to /root/nltk_data...
#        |   Unzipping corpora/ptb.zip.
#        | Downloading package punkt to /root/nltk_data...
#        |   Package punkt is already up-to-date!
#        | Downloading package qc to /root/nltk_data...
#        |   Unzipping corpora/qc.zip.
#        | Downloading package reuters to /root/nltk_data...
#        | Downloading package rslp to /root/nltk_data...
#        |   Unzipping stemmers/rslp.zip.
#        | Downloading package rte to /root/nltk_data...
#        |   Unzipping corpora/rte.zip.
#        | Downloading package sample_grammars to /root/nltk_data...
#        |   Unzipping grammars/sample_grammars.zip.
#        | Downloading package semcor to /root/nltk_data...
#        | Downloading package senseval to /root/nltk_data...
#        |   Unzipping corpora/senseval.zip.
#        | Downloading package sentence_polarity to /root/nltk_data...
#        |   Unzipping corpora/sentence_polarity.zip.
#        | Downloading package sentiwordnet to /root/nltk_data...
#        |   Unzipping corpora/sentiwordnet.zip.
#        | Downloading package shakespeare to /root/nltk_data...
#        |   Unzipping corpora/shakespeare.zip.
#        | Downloading package sinica_treebank to /root/nltk_data...
#        |   Unzipping corpora/sinica_treebank.zip.
#        | Downloading package smultron to /root/nltk_data...
#        |   Unzipping corpora/smultron.zip.
#        | Downloading package snowball_data to /root/nltk_data...
#        | Downloading package spanish_grammars to /root/nltk_data...
#        |   Unzipping grammars/spanish_grammars.zip.
#        | Downloading package state_union to /root/nltk_data...
#        |   Unzipping corpora/state_union.zip.
#        | Downloading package stopwords to /root/nltk_data...
#        |   Package stopwords is already up-to-date!
#        | Downloading package subjectivity to /root/nltk_data...
#        |   Unzipping corpora/subjectivity.zip.
#        | Downloading package swadesh to /root/nltk_data...
#        |   Unzipping corpora/swadesh.zip.
#        | Downloading package switchboard to /root/nltk_data...
#        |   Unzipping corpora/switchboard.zip.
#        | Downloading package tagsets to /root/nltk_data...
#        |   Unzipping help/tagsets.zip.
#        | Downloading package timit to /root/nltk_data...
#        |   Unzipping corpora/timit.zip.
#        | Downloading package toolbox to /root/nltk_data...
#        |   Unzipping corpora/toolbox.zip.
#        | Downloading package treebank to /root/nltk_data...
#        |   Unzipping corpora/treebank.zip.
#        | Downloading package twitter_samples to /root/nltk_data...
#        |   Unzipping corpora/twitter_samples.zip.
#        | Downloading package udhr to /root/nltk_data...
#        |   Unzipping corpora/udhr.zip.
#        | Downloading package udhr2 to /root/nltk_data...
#        |   Unzipping corpora/udhr2.zip.
#        | Downloading package unicode_samples to /root/nltk_data...
#        |   Unzipping corpora/unicode_samples.zip.
#        | Downloading package universal_tagset to /root/nltk_data...
#        |   Unzipping taggers/universal_tagset.zip.
#        | Downloading package universal_treebanks_v20 to
#        |     /root/nltk_data...
#        | Downloading package vader_lexicon to /root/nltk_data...
#        | Downloading package verbnet to /root/nltk_data...
#        |   Unzipping corpora/verbnet.zip.
#        | Downloading package verbnet3 to /root/nltk_data...
#        |   Unzipping corpora/verbnet3.zip.
#        | Downloading package webtext to /root/nltk_data...
#        |   Unzipping corpora/webtext.zip.
#        | Downloading package wmt15_eval to /root/nltk_data...
#        |   Unzipping models/wmt15_eval.zip.
#        | Downloading package word2vec_sample to /root/nltk_data...
#        |   Unzipping models/word2vec_sample.zip.
#        | Downloading package wordnet to /root/nltk_data...
#        |   Package wordnet is already up-to-date!
#        | Downloading package wordnet2021 to /root/nltk_data...
#        | Downloading package wordnet31 to /root/nltk_data...
#        | Downloading package wordnet_ic to /root/nltk_data...
#        |   Unzipping corpora/wordnet_ic.zip.
#        | Downloading package words to /root/nltk_data...
#        |   Unzipping corpora/words.zip.
#        | Downloading package ycoe to /root/nltk_data...
#        |   Unzipping corpora/ycoe.zip.
#        |
#      Done downloading collection all
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %% [markdown]
# Connect to your Google Drive and Load the NLTK Library

# %%
import numpy as np
import nltk
f = open("/content/drive/MyDrive/Colab Notebooks/chatbot.txt", 'r', errors = 'ignore')
raw_doc = f.read()
raw_doc
# Out:
# 'A chatbot (also known as a talkbot, chatterbot, Bot, IM bot, interactive agent, or Artificial Conversational Entity) is a computer program or an artificial intelligence which conducts a conversation via auditory or textual methods. Such programs are often designed to convincingly simulate how a human would behave as a conversational partner, thereby passing the Turing test. Chatbots are typically used in dialog systems for various practical purposes including customer service or information acquisition. Some chatterbots use sophisticated natural language processing systems, but many simpler systems scan for keywords within the input, then pull a reply with the most matching keywords, or the most similar wording pattern, from a database.\n\nThe term "ChatterBot" was originally coined by Michael Mauldin (creator of the first Verbot, Julia) in 1994 to describe these conversational programs.Today, most chatbots are either accessed via virtual assistants such as Google Assistant and Amazon Alexa, via messaging apps such as Facebook Messenger or WeChat, or via individual organizations\' apps and websites. Chatbots can be classified into usage categories such as conversational commerce (e-commerce via chat), analytics, communication, customer support, design, developer tools, education, entertainment, finance, food, games, health, HR, marketing, news, personal, productivity, shopping, social, sports, travel and utilities.\nBackground\nIn 1950, Alan Turing\'s famous article "Computing Machinery and Intelligence" was published, which proposed what is now called the Turing test as a criterion of intelligence. This criterion depends on the ability of a computer program to impersonate a human in a real-time written conversation with a human judge, sufficiently well that the judge is unable to distinguish reliablyon the basis of the conversational content alonebetween the program and a real human. The notoriety of Turing\'s proposed test stimulated great interest in Joseph Weizenbaum\'s program ELIZA, published in 1966, which seemed to be able to fool users into believing that they were conversing with a real human. However Weizenbaum himself did not claim that ELIZA was genuinely intelligent, and the Introduction to his paper presented it more as a debunking exercise:\n\n[In] artificial intelligence ... machines are made to behave in wondrous ways, often sufficient to dazzle even the most experienced observer. But once a particular program is unmasked, once its inner workings are explained ... its magic crumbles away; it stands revealed as a mere collection of procedures ... The observer says to himself "I could have written that". With that thought he moves the program in question from the shelf marked "intelligent", to that reserved for curios ... The object of this paper is to cause just such a re-evaluation of the program about to be "explained". Few programs ever needed it more.\n\nELIZA\'s key method of operation (copied by chatbot designers ever since) involves the recognition of cue words or phrases in the input, and the output of corresponding pre-prepared or pre-programmed responses that can move the conversation forward in an apparently meaningful way (e.g. by responding to any input that contains the word \'MOTHER\' with \'TELL ME MORE ABOUT YOUR FAMILY\').Thus an illusion of understanding is generated, even though the processing involved has been merely superficial. ELIZA showed that such an illusion is surprisingly easy to generate, because human judges are so ready to give the benefit of the doubt when conversational responses are capable of being interpreted as "intelligent".\n\nInterface designers have come to appreciate that humans\' readiness to interpret computer output as genuinely conversationaleven when it is actually based on rather simple pattern-matchingcan be exploited for useful purposes. Most people prefer to engage with programs that are human-like, and this gives chatbot-style techniques a potentially usefu ...

# %% [markdown]
# DATA PREPROCESSING - TEXT CASE HANDLING
# Convert all the data coming as an input to either upper or lower case.
# This will avoid misrepresentation and misinterpretation of words spelled with lower or upper cases.

# %%
raw_doc = raw_doc.lower() #converts text to lowercase

# %% [markdown]
# TOKENIZATION
# Tokenization is the structured process of converting a sentence into an individual collection of elements called tokens. It is also used to understand the importance of each of the words with respect to the sentence. These so-called tokens can be words, numbers, or punctuation marks.
# Sentence Tokenization: It is the process of tokenizing a text into sentences. To do this, we use the method sent_tokenize as shown in the below code.
# Word Tokenization: It is the process of tokenizing sentences or text into words and punctuation. To do so, we use the method word_tokenize as shown in the below code.

# %%
nltk.download('punkt') #using the punkt tokenizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('wordnet') #using the wordNet dictionary
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.tokenize import word_tokenize

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
sent_tokens = nltk.sent_tokenize(raw_doc) #converts doc to list of sentences
word_tokens = nltk.word_tokenize(raw_doc) #converts doc to list of words

# %%
sent_tokens
# Out:
# ['a chatbot (also known as a talkbot, chatterbot, bot, im bot, interactive agent, or artificial conversational entity) is a computer program or an artificial intelligence which conducts a conversation via auditory or textual methods.',
#  'such programs are often designed to convincingly simulate how a human would behave as a conversational partner, thereby passing the turing test.',
#  'chatbots are typically used in dialog systems for various practical purposes including customer service or information acquisition.',
#  'some chatterbots use sophisticated natural language processing systems, but many simpler systems scan for keywords within the input, then pull a reply with the most matching keywords, or the most similar wording pattern, from a database.',
#  'the term "chatterbot" was originally coined by michael mauldin (creator of the first verbot, julia) in 1994 to describe these conversational programs.today, most chatbots are either accessed via virtual assistants such as google assistant and amazon alexa, via messaging apps such as facebook messenger or wechat, or via individual organizations\' apps and websites.',
#  'chatbots can be classified into usage categories such as conversational commerce (e-commerce via chat), analytics, communication, customer support, design, developer tools, education, entertainment, finance, food, games, health, hr, marketing, news, personal, productivity, shopping, social, sports, travel and utilities.',
#  'background\nin 1950, alan turing\'s famous article "computing machinery and intelligence" was published, which proposed what is now called the turing test as a criterion of intelligence.',
#  'this criterion depends on the ability of a computer program to impersonate a human in a real-time written conversation with a human judge, sufficiently well that the judge is unable to distinguish reliablyon the basis of the conversational content alonebetween the program and a real human.',
#  "the notoriety of turing's proposed test stimulated great interest in joseph weizenbaum's program eliza, published in 1966, which seemed to be able to fool users into believing that they were conversing with a real human.",
#  'however weizenbaum himself did not claim that eliza was genuinely intelligent, and the introduction to his paper presented it more as a debunking exercise:\n\n[in] artificial intelligence ... machines are made to behave in wondrous ways, often sufficient to dazzle even the most experienced observer.',
#  'but once a particular program is unmasked, once its inner workings are explained ... its magic crumbles away; it stands revealed as a mere collection of procedures ... the observer says to himself "i could have written that".',
#  'with that thought he moves the program in question from the shelf marked "intelligent", to that reserved for curios ... the object of this paper is to cause just such a re-evaluation of the program about to be "explained".',
#  'few programs ever needed it more.',
#  "eliza's key method of operation (copied by chatbot designers ever since) involves the recognition of cue words or phrases in the input, and the output of corresponding pre-prepared or pre-programmed responses that can move the conversation forward in an apparently meaningful way (e.g.",
#  "by responding to any input that contains the word 'mother' with 'tell me more about your family').thus an illusion of understanding is generated, even though the processing involved has been merely superficial.",
#  'eliza showed that such an illusion is surprisingly easy to generate, because human judges are so ready to give the benefit of the doubt when conversational responses are capable of being interpreted as "intelligent".',
#  "interface designers have come to appreciate that humans' readiness to interpret computer output as genuinely conversationaleven when it is actually based on rather simple pattern-matchingcan be exploited for useful purposes.",
#  'most people prefer to engage with programs that are human-like, and this gives chatbot-style techniques a potentially useful role in interactive systems that need to elicit information from users, as long as that information is relatively straightforward and falls into predictable categories.',
#  'thus, for example, online help systems can usefully employ chatbot techniques to identify the area of help that users require, potentially providing a "friendlier" interface than a more formal search or menu system.',
#  'this sort of usage holds the prospect of moving chatbot technology from weizenbaum\'s "shelf ... reserved for curios" to that marked "genuinely useful computational methods".',
#  'development\nthe classic historic early chatbots are eliza (1966) and parry (1972).more recent notable programs include a.l.i.c.e., jabberwacky and d.u.d.e (agence nationale de la recherche and cnrs 2006).',
#  'while eliza and parry were used exclusively to simulate typed conversation, many chatbots now include functional features such as games and web searching abilities.',
#  "in 1984, a book called the policeman's beard is half constructed was published, allegedly written by the chatbot racter (though the program as released would not have been capable of doing so).",
#  'one pertinent field of ai research is natural language processing.',
#  'usually, weak ai fields employ specialized software or programming languages created specifically for the narrow function required.',
#  'for example, a.l.i.c.e.',
#  'uses a markup language called aiml, which is specific to its function as a conversational agent, and has since been adopted by various other developers of, so called, alicebots.',
#  'nevertheless, a.l.i.c.e.',
#  'is still purely based on pattern matching techniques without any reasoning capabilities, the same technique eliza was using back in 1966. this is not strong ai, which would require sapience and logical reasoning abilities.',
#  'jabberwacky learns new responses and context based on real-time user interactions, rather than being driven from a static database.',
#  'some more recent chatbots also combine real-time learning with evolutionary algorithms that optimise their ability to communicate based on each conversation held.',
#  'still, there is currently no general purpose conversational artificial intelligence, and some software developers focus on the practical aspect, information retrieval.',
#  'chatbot competitions focus on the turing test or more specific goals.',
#  'two such annual contests are the loebner prize and the chatterbox challenge (offline since 2015, materials can still be found from web archives).',
#  'according to forrester (2015), ai will replace 16 percent of american jobs by the end of the decade.chatbots have been used in applications such as customer service, sales and product education.',
#  'however, a study conducted by narrative science in 2015 found that 80 percent of their respondents believe ai improves worker performance and creates jobs.',
#  "[citation needed]\n\napplication\nsee also: virtual assistant\n\naeromexico airline chatbot running on facebook messenger, march 2018\nmessaging apps\nmany companies' chatbots run on messaging apps like facebook messenger (since 2016), wechat (since 2013),whatsapp, livechat, kik, slack, line, telegram, or simply via sms.",
#  'they are used for b2c customer service, sales and marketing.',
#  'in 2016, facebook messenger allowed developers to place chatbots on their platform.',
#  'there were 30,000 bots created for messenger in the first six months, rising to 100,000 by september 2017.\n\nsince september 2017, this has also been as part of a pilot program on whatsapp.',
#  'airlines klm and aeromxico both announced their participation in the testing;both airlines had previously launched customer services on the facebook messenger platform.',
#  "the bots usually appear as one of the user's contacts, but can sometimes act as participants in a group chat.",
#  'many banks and insurers, media and e-commerce companies, airlines and hotel chains, retailers, health care providers, government entities and restaurant chains have used chatbots to answer simple questions, increase customer engagement,for promotion, and to offer additional ways to order from them.',
#  'a 2017 study showed 4% of companies used chatbots.according to a 2016 study, 80% of businesses said they intended to have one by 2020.\n\nas part of company apps and websites\nprevious generations of chatbots were present on company websites, e.g.',
#  'ask jenn from alaska airlines which debuted in 2008 or expedia\'s virtual customer service agent which launched in 2011.the newer generation of chatbots includes ibm watson-powered "rocky", introduced in february 2017 by the new york city-based e-commerce company rare carat to provide information to prospective diamond buyers.',
#  'company internal platforms\nother companies explore ways they can use chatbots internally, for example for customer support, human resources, or even in internet-of-things (iot) projects.',
#  'overstock.com, for one, has reportedly launched a chatbot named mila to automate certain simple yet time-consuming processes when requesting for a sick leave.other large companies such as lloyds banking group, royal bank of scotland, renault and citron are now using automated online assistants instead of call centres with humans to provide a first point of contact.',
#  'a saas chatbot business ecosystem has been steadily growing since the f8 conference when zuckerberg unveiled that messenger would allow chatbots into the app.',
#  'toys\nchatbots have also been incorporated into devices not primarily meant for computing such as toys.',
#  "hello barbie is an internet-connected version of the doll that uses a chatbot provided by the company toytalk,which previously used the chatbot for a range of smartphone-based characters for children.these characters' behaviors are constrained by a set of rules that in effect emulate a particular character and produce a storyline.",
#  "ibm's watson computer has been used as the basis for chatbot-based educational toys for companies such as cognitoys intended to interact with children for educational purposes.",
#  'chatbot creation\nthe process of creating a chatbot follows a pattern similar to the development of a web page or a mobile app.',
#  'it can be divided into design, building, analytics and maintenance.',
#  'design\nthe chatbot design is the process that defines the interaction between the user and the chatbot.the chatbot designer will define the chatbot personality, the questions that will be asked to the users, and the overall interaction.it can be viewed as a subset of the conversational design.',
#  'in order to speed up this process, designers can use dedicated chatbot design tools, that allow for immediate preview, team collaboration and video export.an important part of the chatbot design is also centered around user testing.',
#  'user testing can be performed following the same principles that guide the user testing of graphical interfaces.',
#  "building\nthe process of building a chatbot can be divided into two main tasks: understanding the user's intent and producing the correct answer.",
#  'the first task involves understanding the user input.',
#  'in order to properly understand a user input in a free text form, a natural language processing engine can be used.the second task may involve different approaches depending on the type of the response that the chatbot will generate.',
#  'analytics\nthe usage of the chatbot can be monitored in order to spot potential flaws or problems.',
#  'it can also provide useful insights that can improve the final user experience.',
#  'maintenance\nto keep chatbots up to speed with changing company products and services, traditional chatbot development platforms require ongoing maintenance.',
#  'this can either be in the form of an ongoing service provider or for larger enterprises in the form of an in-house chatbot training team.to eliminate these costs, some startups are experimenting with artificial intelligence to develop self-learning chatbots, particularly in customer service applications.',
#  'chatbot development platforms\nthe process of building, testing and deploying chatbots can be done on cloud based chatbot development platforms offered by cloud platform as a service (paas) providers such as yekaliva, oracle cloud platform, snatchbot and ibm watson.these cloud platforms provide natural language processing, artificial intelligence and mobile backend as a service for chatbot development.',
#  'apis\nthere are many apis available for building your own chatbots, such as aarc.',
#  'malicious use\nmalicious chatbots are frequently used to fill chat rooms with spam and advertisements, by mimicking human behaviour and conversations or to entice people into revealing personal information, such as bank account numbers.',
#  'they are commonly found on yahoo!',
#  'messenger, windows live messenger, aol instant messenger and other instant messaging protocols.',
#  "there has also been a published report of a chatbot used in a fake personal ad on a dating service's website."]

# %%
word_tokens
# Out:
# ['a',
#  'chatbot',
#  '(',
#  'also',
#  'known',
#  'as',
#  'a',
#  'talkbot',
#  ',',
#  'chatterbot',
#  ',',
#  'bot',
#  ',',
#  'im',
#  'bot',
#  ',',
#  'interactive',
#  'agent',
#  ',',
#  'or',
#  'artificial',
#  'conversational',
#  'entity',
#  ')',
#  'is',
#  'a',
#  'computer',
#  'program',
#  'or',
#  'an',
#  'artificial',
#  'intelligence',
#  'which',
#  'conducts',
#  'a',
#  'conversation',
#  'via',
#  'auditory',
#  'or',
#  'textual',
#  'methods',
#  '.',
#  'such',
#  'programs',
#  'are',
#  'often',
#  'designed',
#  'to',
#  'convincingly',
#  'simulate',
#  'how',
#  'a',
#  'human',
#  'would',
#  'behave',
#  'as',
#  'a',
#  'conversational',
#  'partner',
#  ',',
#  'thereby',
#  'passing',
#  'the',
#  'turing',
#  'test',
#  '.',
#  'chatbots',
#  'are',
#  'typically',
#  'used',
#  'in',
#  'dialog',
#  'systems',
#  'for',
#  'various',
#  'practical',
#  'purposes',
#  'including',
#  'customer',
#  'service',
#  'or',
#  'information',
#  'acquisition',
#  '.',
#  'some',
#  'chatterbots',
#  'use',
#  'sophisticated',
#  'natural',
#  'language',
#  'processing',
#  'systems',
#  ',',
#  'but',
#  'many',
#  'simpler',
#  'systems',
#  'scan',
#  'for',
#  'keywords',
#  'within',
#  'the',
#  'input',
#  ',',
#  'then',
#  'pull',
#  'a',
#  'reply',
#  'with',
#  'the',
#  'most',
#  'matching',
#  'keywords',
#  ',',
#  'or',
#  'the',
#  'most',
#  'similar',
#  'wording',
#  'pattern',
#  ',',
#  'from',
#  'a',
#  'database',
#  '.',
#  'the',
#  'term',
#  '``',
#  'chatterbot',
#  "''",
#  'was',
#  'originally',
#  'coined',
#  'by',
#  'michael',
#  'mauldin',
#  '(',
#  'creator',
#  'of',
#  'the',
#  'first',
#  'verbot',
#  ',',
#  'julia',
#  ')',
#  'in',
#  '1994',
#  'to',
#  'describe',
#  'these',
#  'conversational',
#  'programs.today',
#  ',',
#  'most',
#  'chatbots',
#  'are',
#  'either',
#  'accessed',
#  'via',
#  'virtual',
#  'assistants',
#  'such',
#  'as',
#  'google',
#  'assistant',
#  'and',
#  'amazon',
#  'alexa',
#  ',',
#  'via',
#  'messaging',
#  'apps',
#  'such',
#  'as',
#  'facebook',
#  'messenger',
#  'or',
#  'wechat',
#  ',',
#  'or',
#  'via',
#  'individual',
#  'organizations',
#  "'",
#  'apps',
#  'and',
#  'websites',
#  '.',
#  'chatbots',
#  'can',
#  'be',
#  'classified',
#  'into',
#  'usage',
#  'categories',
#  'such',
#  'as',
#  'conversational',
#  'commerce',
#  '(',
#  'e-commerce',
#  'via',
#  'chat',
#  ')',
#  ',',
#  'analytics',
#  ',',
#  'communication',
#  ',',
#  'customer',
#  'support',
#  ',',
#  'design',
#  ',',
#  'developer',
#  'tools',
#  ',',
#  'education',
#  ',',
#  'entertainment',
#  ',',
#  'finance',
#  ',',
#  'food',
#  ',',
#  'games',
#  ',',
#  'health',
#  ',',
#  'hr',
#  ',',
#  'marketing',
#  ',',
#  'news',
#  ',',
#  'personal',
#  ',',
#  'productivity',
#  ',',
#  'shopping',
#  ',',
#  'social',
#  ',',
#  'sports',
#  ',',
#  'travel',
#  'and',
#  'utilities',
#  '.',
#  'background',
#  'in',
#  '1950',
#  ',',
#  'alan',
#  'turing',
#  "'s",
#  'famous',
#  'article',
#  '``',
#  'computing',
#  'machinery',
#  'and',
#  'intelligence',
#  "''",
#  'was',
#  'published',
#  ',',
#  'which',
#  'proposed',
#  'what',
#  'is',
#  'now',
#  'called',
#  'the',
#  'turing',
#  'test',
#  'as',
#  'a',
#  'criterion',
#  'of',
#  'intelligence',
#  '.',
#  'this',
#  'criterion',
#  'depends',
#  'on',
#  'the',
#  'ability',
#  'of',
#  'a',
#  'computer',
#  'program',
#  'to',
#  'impersonate',
#  'a',
#  'human',
#  'in',
#  'a',
#  'real-time',
#  'written',
#  'conversation',
#  'with',
#  'a',
#  'human',
#  'judge',
#  ',',
#  'sufficiently',
#  'well',
#  'that',
#  'the',
#  'judge',
#  'is',
#  'unable',
#  'to',
#  'distinguish',
#  'reliablyon',
#  'the',
#  'basis',
#  'of',
#  'the',
#  'conversational',
#  'content',
#  'alonebetween',
#  'the',
#  'program',
#  'and',
#  'a',
#  'real',
#  'human',
#  '.',
#  'the',
#  'notoriety',
#  'of',
#  'turing',
#  "'s",
#  'proposed',
#  'test',
#  'stimulated',
#  'great',
#  'interest',
#  'in',
#  'joseph',
#  'weizenbaum',
#  "'s",
#  'program',
#  'eliza',
#  ',',
#  'published',
#  'in',
#  '1966',
#  ',',
#  'which',
#  'seemed',
#  'to',
#  'be',
#  'able',
#  'to',
#  'fool',
#  'users',
#  'into',
#  'believing',
#  'that',
#  'they',
#  'were',
#  'conversing',
#  'with',
#  'a',
#  'real',
#  'human',
#  '.',
#  'however',
#  'weizenbaum',
#  'himself',
#  'did',
#  'not',
#  'claim',
#  'that',
#  'eliza',
#  'was',
#  'genuinely',
#  'intelligent',
#  ',',
#  'and',
#  'the',
#  'introduction',
#  'to',
#  'his',
#  'paper',
#  'presented',
#  'it',
#  'more',
#  'as',
#  'a',
#  'debunking',
#  'exercise',
#  ':',
#  '[',
#  'in',
#  ']',
#  'artificial',
#  'intelligence',
#  '...',
#  'machines',
#  'are',
#  'made',
#  'to',
#  'behave',
#  'in',
#  'wondrous',
#  'ways',
#  ',',
#  'often',
#  'sufficient',
#  'to',
#  'dazzle',
#  'even',
#  'the',
#  'most',
#  'experienced',
#  'observer',
#  '.',
#  'but',
#  'once',
#  'a',
#  'particular',
#  'program',
#  'is',
#  'unmasked',
#  ',',
#  'once',
#  'its',
#  'inner',
#  'workings',
#  'are',
#  'explained',
#  '...',
#  'its',
#  'magic',
#  'crumbles',
#  'away',
#  ';',
#  'it',
#  'stands',
#  'revealed',
#  'as',
#  'a',
#  'mere',
#  'collection',
#  'of',
#  'procedures',
#  '...',
#  'the',
#  'observer',
#  'says',
#  'to',
#  'himself',
#  '``',
#  'i',
#  'could',
#  'have',
#  'written',
#  'that',
#  "''",
#  '.',
#  'with',
#  'that',
#  'thought',
#  'he',
#  'moves',
#  'the',
#  'program',
#  'in',
#  'question',
#  'from',
#  'the',
#  'shelf',
#  'marked',
#  '``',
#  'intelligent',
#  "''",
#  ',',
#  'to',
#  'that',
#  'reserved',
#  'for',
#  'curios',
#  '...',
#  'the',
#  'object',
#  'of',
#  'this',
#  'paper',
#  'is',
#  'to',
#  'cause',
#  'just',
#  'such',
#  'a',
#  're-evaluation',
#  'of',
#  'the',
#  'program',
#  'about',
#  'to',
#  'be',
#  '``',
#  'explained',
#  "''",
#  '.',
#  'few',
#  'programs',
#  'ever',
#  'needed',
#  'it',
#  'more',
#  '.',
#  'eliza',
#  "'s",
#  'key',
#  'method',
#  'of',
#  'operation',
#  '(',
#  'copied',
#  'by',
#  'chatbot',
#  'designers',
#  'ever',
#  'since',
#  ')',
#  'involves',
#  'the',
#  'recognition',
#  'of',
#  'cue',
#  'words',
#  'or',
#  'phrases',
#  'in',
#  'the',
#  'input',
#  ',',
#  'and',
#  'the',
#  'output',
#  'of',
#  'corresponding',
#  'pre-prepared',
#  'or',
#  'pre-programmed',
#  'responses',
#  'that',
#  'can',
#  'move',
#  'the',
#  'conversation',
#  'forward',
#  'in',
#  'an',
#  'apparently',
#  'meaningful',
#  'way',
#  '(',
#  'e.g',
#  '.',
#  'by',
#  'responding',
#  'to',
#  'any',
#  'input',
#  'that',
#  'contains',
#  'the',
#  'word',
#  "'mother",
#  "'",
#  'with',
#  "'tell",
#  'me',
#  'more',
#  'about',
#  'your',
#  'family',
#  "'",
#  ')',
#  '.thus',
#  'an',
#  'illusion',
#  'of',
#  'understanding',
#  'is',
#  'generated',
#  ',',
#  'even',
#  'though',
#  'the',
#  'processing',
#  'involved',
#  'has',
#  'been',
#  'merely',
#  'superficial',
#  '.',
#  'eliza',
#  'showed',
#  'that',
#  'such',
#  'an',
#  'illusion',
#  'is',
#  'surprisingly',
#  'easy',
#  'to',
#  'generate',
#  ',',
#  'because',
#  'human',
#  'judges',
#  'are',
#  'so',
#  'ready',
#  'to',
#  'give',
#  'the',
#  'benefit',
#  'of',
#  'the',
#  'doubt',
#  'when',
#  'conversational',
#  'responses',
#  'are',
#  'capable',
#  'of',
#  'being',
#  'interpreted',
#  'as',
#  '``',
#  'intelligent',
#  "''",
#  '.',
#  'interface',
#  'designers',
#  'have',
#  'come',
#  'to',
#  'appreciate',
#  'that',
#  'humans',
#  "'",
#  'readiness',
#  'to',
#  'interpret',
#  'computer',
#  'output',
#  'as',
#  'genuinely',
#  'conversationaleven',
#  'when',
#  'it',
#  'is',
#  'actually',
#  'based',
#  'on',
#  'rather',
#  'simple',
#  'pattern-matchingcan',
#  'be',
#  'exploited',
#  'for',
#  'useful',
#  'purposes',
#  '.',
#  'most',
#  'people',
#  'prefer',
#  'to',
#  'engage',
#  'with',
#  'programs',
#  'that',
#  'are',
#  'human-like',
#  ',',
#  'and',
#  'this',
#  'gives',
#  'chatbot-style',
#  'techniques',
#  'a',
#  'potentially',
#  'useful',
#  'role',
#  'in',
#  'interactive',
#  'systems',
#  'that',
#  'need',
#  'to',
#  'elicit',
#  'information',
#  'from',
#  'users',
#  ',',
#  'as',
#  'long',
#  'as',
#  'that',
#  'information',
#  'is',
#  'relatively',
#  'straightforward',
#  'and',
#  'falls',
#  'into',
#  'predictable',
#  'categories',
#  '.',
#  'thus',
#  ',',
#  'for',
#  'example',
#  ',',
#  'online',
#  'help',
#  'systems',
#  'can',
#  'usefully',
#  'employ',
#  'chatbot',
#  'techniques',
#  'to',
#  'identify',
#  'the',
#  'area',
#  'of',
#  'help',
#  'that',
#  'users',
#  'require',
#  ',',
#  'potentially',
#  'providing',
#  'a',
#  '``',
#  'friendlier',
#  "''",
#  'interface',
#  'than',
#  'a',
#  'more',
#  'formal',
#  'search',
#  'or',
#  'menu',
#  'system',
#  '.',
#  'this',
#  'sort',
#  'of',
#  'usage',
#  'holds',
#  'the',
#  'prospect',
#  'of',
#  'moving',
#  'chatbot',
#  'technology',
#  'from',
#  'weizenbaum',
#  "'s",
#  '``',
#  'shelf',
#  '...',
#  'reserved',
#  'for',
#  'curios',
#  "''",
#  'to',
#  'that',
#  'marked',
#  '``',
#  'genuinely',
#  'useful',
#  'computational',
#  'methods',
#  "''",
#  '.',
#  'development',
#  'the',
#  'classic',
#  'historic',
#  'early',
#  'chatbots',
#  'are',
#  'eliza',
#  '(',
#  '1966',
#  ')',
#  'and',
#  'parry',
#  '(',
#  '1972',
#  ')',
#  '.more',
#  'recent',
#  'notable',
#  'programs',
#  'include',
#  'a.l.i.c.e.',
#  ',',
#  'jabberwacky',
#  'and',
#  'd.u.d.e',
#  '(',
#  'agence',
#  'nationale',
#  'de',
#  'la',
#  'recherche',
#  'and',
#  'cnrs',
#  '2006',
#  ')',
#  '.',
#  'while',
#  'eliza',
#  'and',
#  'parry',
#  'were',
#  'used',
#  'exclusively',
#  'to',
#  'simulate',
#  'typed',
#  'conversation',
#  ',',
#  'many',
#  'chatbots',
#  'now',
#  'include',
#  'functional',
#  'features',
#  'such',
#  'as',
#  'games',
#  'and',
#  'web',
#  'searching',
#  'abilities',
#  '.',
#  'in',
#  '1984',
#  ',',
#  'a',
#  'book',
#  'called',
#  'the',
#  'policeman',
#  "'s",
#  'beard',
#  'is',
#  'half',
#  'constructed',
#  'was',
#  'published',
#  ',',
#  'allegedly',
#  'written',
#  'by',
#  'the',
#  'chatbot',
#  'racter',
#  '(',
#  'though',
#  'the',
#  'program',
#  'as',
#  'released',
#  'would',
#  'not',
#  'have',
#  'been',
#  'capable',
#  'of',
#  'doing',
#  'so',
#  ')',
#  '.',
#  'one',
#  'pertinent',
#  'field',
#  'of',
#  'ai',
#  'research',
#  'is',
#  'natural',
#  'language',
#  'processing',
#  '.',
#  'usually',
#  ',',
#  'weak',
#  'ai',
#  'fields',
#  'employ',
#  'specialized',
#  'software',
#  'or',
#  'programming',
#  'languages',
#  'created',
#  'specifically',
#  'for',
#  'the',
#  'narrow',
#  'function',
#  'required',
#  '.',
#  'for',
#  'example',
#  ',',
#  'a.l.i.c.e',
#  '.',
#  'uses',
#  'a',
#  'markup',
#  'language',
#  'called',
#  'aiml',
#  ',',
#  'which',
#  'is',
#  'specific',
#  'to',
#  'its',
#  'function',
#  'as',
#  'a',
#  'conversational',
#  'agent',
#  ',',
#  'and',
#  'has',
#  'since',
#  'been',
#  'adopted',
#  'by',
#  'various',
#  'other',
#  'developers',
#  'of',
#  ',',
#  'so',
#  'called',
#  ',',
#  'alicebots',
#  '.',
#  'nevertheless',
#  ',',
#  'a.l.i.c.e',
#  '.',
#  'is',
#  'still',
#  'purely',
#  'based',
#  'on',
#  'pattern',
#  'matching',
#  'techniques',
#  'without',
#  'any',
#  'reasoning',
#  'capabilities',
#  ',',
#  'the',
#  'same',
#  'technique',
#  'eliza',
#  'was',
#  'using',
#  'back',
#  'in',
#  '1966.',
#  'this',
#  'is',
#  'not',
#  'strong',
#  'ai',
#  ',',
#  'which',
#  'would',
#  'require',
#  'sapience',
#  'and',
#  'logical',
#  'reasoning',
#  'abilities',
#  '.',
#  'jabberwacky',
#  ...]

# %%
import re
clean_data = []
for words in word_tokens:
  item = []
  result = re.sub(r"[^\w\s]", "", words)
  if result != "":
     clean_data.append(result)

# %% [markdown]
# REMOVING STOP WORDS
# Words that have very little meaning or little usage are considered stop words. For example, words such as “a”, “the”, “an”, “is”, etc are some of the stop words.

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
clean_data_1 = []

# %%
for words in clean_data:
  if not words in stopwords.words('english'):
      clean_data_1.append(words)

# %%
clean_data_1
# Out:
# ['chatbot',
#  'also',
#  'known',
#  'talkbot',
#  'chatterbot',
#  'bot',
#  'im',
#  'bot',
#  'interactive',
#  'agent',
#  'artificial',
#  'conversational',
#  'entity',
#  'computer',
#  'program',
#  'artificial',
#  'intelligence',
#  'conducts',
#  'conversation',
#  'via',
#  'auditory',
#  'textual',
#  'methods',
#  'programs',
#  'often',
#  'designed',
#  'convincingly',
#  'simulate',
#  'human',
#  'would',
#  'behave',
#  'conversational',
#  'partner',
#  'thereby',
#  'passing',
#  'turing',
#  'test',
#  'chatbots',
#  'typically',
#  'used',
#  'dialog',
#  'systems',
#  'various',
#  'practical',
#  'purposes',
#  'including',
#  'customer',
#  'service',
#  'information',
#  'acquisition',
#  'chatterbots',
#  'use',
#  'sophisticated',
#  'natural',
#  'language',
#  'processing',
#  'systems',
#  'many',
#  'simpler',
#  'systems',
#  'scan',
#  'keywords',
#  'within',
#  'input',
#  'pull',
#  'reply',
#  'matching',
#  'keywords',
#  'similar',
#  'wording',
#  'pattern',
#  'database',
#  'term',
#  'chatterbot',
#  'originally',
#  'coined',
#  'michael',
#  'mauldin',
#  'creator',
#  'first',
#  'verbot',
#  'julia',
#  '1994',
#  'describe',
#  'conversational',
#  'programstoday',
#  'chatbots',
#  'either',
#  'accessed',
#  'via',
#  'virtual',
#  'assistants',
#  'google',
#  'assistant',
#  'amazon',
#  'alexa',
#  'via',
#  'messaging',
#  'apps',
#  'facebook',
#  'messenger',
#  'wechat',
#  'via',
#  'individual',
#  'organizations',
#  'apps',
#  'websites',
#  'chatbots',
#  'classified',
#  'usage',
#  'categories',
#  'conversational',
#  'commerce',
#  'ecommerce',
#  'via',
#  'chat',
#  'analytics',
#  'communication',
#  'customer',
#  'support',
#  'design',
#  'developer',
#  'tools',
#  'education',
#  'entertainment',
#  'finance',
#  'food',
#  'games',
#  'health',
#  'hr',
#  'marketing',
#  'news',
#  'personal',
#  'productivity',
#  'shopping',
#  'social',
#  'sports',
#  'travel',
#  'utilities',
#  'background',
#  '1950',
#  'alan',
#  'turing',
#  'famous',
#  'article',
#  'computing',
#  'machinery',
#  'intelligence',
#  'published',
#  'proposed',
#  'called',
#  'turing',
#  'test',
#  'criterion',
#  'intelligence',
#  'criterion',
#  'depends',
#  'ability',
#  'computer',
#  'program',
#  'impersonate',
#  'human',
#  'realtime',
#  'written',
#  'conversation',
#  'human',
#  'judge',
#  'sufficiently',
#  'well',
#  'judge',
#  'unable',
#  'distinguish',
#  'reliablyon',
#  'basis',
#  'conversational',
#  'content',
#  'alonebetween',
#  'program',
#  'real',
#  'human',
#  'notoriety',
#  'turing',
#  'proposed',
#  'test',
#  'stimulated',
#  'great',
#  'interest',
#  'joseph',
#  'weizenbaum',
#  'program',
#  'eliza',
#  'published',
#  '1966',
#  'seemed',
#  'able',
#  'fool',
#  'users',
#  'believing',
#  'conversing',
#  'real',
#  'human',
#  'however',
#  'weizenbaum',
#  'claim',
#  'eliza',
#  'genuinely',
#  'intelligent',
#  'introduction',
#  'paper',
#  'presented',
#  'debunking',
#  'exercise',
#  'artificial',
#  'intelligence',
#  'machines',
#  'made',
#  'behave',
#  'wondrous',
#  'ways',
#  'often',
#  'sufficient',
#  'dazzle',
#  'even',
#  'experienced',
#  'observer',
#  'particular',
#  'program',
#  'unmasked',
#  'inner',
#  'workings',
#  'explained',
#  'magic',
#  'crumbles',
#  'away',
#  'stands',
#  'revealed',
#  'mere',
#  'collection',
#  'procedures',
#  'observer',
#  'says',
#  'could',
#  'written',
#  'thought',
#  'moves',
#  'program',
#  'question',
#  'shelf',
#  'marked',
#  'intelligent',
#  'reserved',
#  'curios',
#  'object',
#  'paper',
#  'cause',
#  'reevaluation',
#  'program',
#  'explained',
#  'programs',
#  'ever',
#  'needed',
#  'eliza',
#  'key',
#  'method',
#  'operation',
#  'copied',
#  'chatbot',
#  'designers',
#  'ever',
#  'since',
#  'involves',
#  'recognition',
#  'cue',
#  'words',
#  'phrases',
#  'input',
#  'output',
#  'corresponding',
#  'preprepared',
#  'preprogrammed',
#  'responses',
#  'move',
#  'conversation',
#  'forward',
#  'apparently',
#  'meaningful',
#  'way',
#  'eg',
#  'responding',
#  'input',
#  'contains',
#  'word',
#  'mother',
#  'tell',
#  'family',
#  'thus',
#  'illusion',
#  'understanding',
#  'generated',
#  'even',
#  'though',
#  'processing',
#  'involved',
#  'merely',
#  'superficial',
#  'eliza',
#  'showed',
#  'illusion',
#  'surprisingly',
#  'easy',
#  'generate',
#  'human',
#  'judges',
#  'ready',
#  'give',
#  'benefit',
#  'doubt',
#  'conversational',
#  'responses',
#  'capable',
#  'interpreted',
#  'intelligent',
#  'interface',
#  'designers',
#  'come',
#  'appreciate',
#  'humans',
#  'readiness',
#  'interpret',
#  'computer',
#  'output',
#  'genuinely',
#  'conversationaleven',
#  'actually',
#  'based',
#  'rather',
#  'simple',
#  'patternmatchingcan',
#  'exploited',
#  'useful',
#  'purposes',
#  'people',
#  'prefer',
#  'engage',
#  'programs',
#  'humanlike',
#  'gives',
#  'chatbotstyle',
#  'techniques',
#  'potentially',
#  'useful',
#  'role',
#  'interactive',
#  'systems',
#  'need',
#  'elicit',
#  'information',
#  'users',
#  'long',
#  'information',
#  'relatively',
#  'straightforward',
#  'falls',
#  'predictable',
#  'categories',
#  'thus',
#  'example',
#  'online',
#  'help',
#  'systems',
#  'usefully',
#  'employ',
#  'chatbot',
#  'techniques',
#  'identify',
#  'area',
#  'help',
#  'users',
#  'require',
#  'potentially',
#  'providing',
#  'friendlier',
#  'interface',
#  'formal',
#  'search',
#  'menu',
#  'system',
#  'sort',
#  'usage',
#  'holds',
#  'prospect',
#  'moving',
#  'chatbot',
#  'technology',
#  'weizenbaum',
#  'shelf',
#  'reserved',
#  'curios',
#  'marked',
#  'genuinely',
#  'useful',
#  'computational',
#  'methods',
#  'development',
#  'classic',
#  'historic',
#  'early',
#  'chatbots',
#  'eliza',
#  '1966',
#  'parry',
#  '1972',
#  'recent',
#  'notable',
#  'programs',
#  'include',
#  'alice',
#  'jabberwacky',
#  'dude',
#  'agence',
#  'nationale',
#  'de',
#  'la',
#  'recherche',
#  'cnrs',
#  '2006',
#  'eliza',
#  'parry',
#  'used',
#  'exclusively',
#  'simulate',
#  'typed',
#  'conversation',
#  'many',
#  'chatbots',
#  'include',
#  'functional',
#  'features',
#  'games',
#  'web',
#  'searching',
#  'abilities',
#  '1984',
#  'book',
#  'called',
#  'policeman',
#  'beard',
#  'half',
#  'constructed',
#  'published',
#  'allegedly',
#  'written',
#  'chatbot',
#  'racter',
#  'though',
#  'program',
#  'released',
#  'would',
#  'capable',
#  'one',
#  'pertinent',
#  'field',
#  'ai',
#  'research',
#  'natural',
#  'language',
#  'processing',
#  'usually',
#  'weak',
#  'ai',
#  'fields',
#  'employ',
#  'specialized',
#  'software',
#  'programming',
#  'languages',
#  'created',
#  'specifically',
#  'narrow',
#  'function',
#  'required',
#  'example',
#  'alice',
#  'uses',
#  'markup',
#  'language',
#  'called',
#  'aiml',
#  'specific',
#  'function',
#  'conversational',
#  'agent',
#  'since',
#  'adopted',
#  'various',
#  'developers',
#  'called',
#  'alicebots',
#  'nevertheless',
#  'alice',
#  'still',
#  'purely',
#  'based',
#  'pattern',
#  'matching',
#  'techniques',
#  'without',
#  'reasoning',
#  'capabilities',
#  'technique',
#  'eliza',
#  'using',
#  'back',
#  '1966',
#  'strong',
#  'ai',
#  'would',
#  'require',
#  'sapience',
#  'logical',
#  'reasoning',
#  'abilities',
#  'jabberwacky',
#  'learns',
#  'new',
#  'responses',
#  'context',
#  'based',
#  'realtime',
#  'user',
#  'interactions',
#  'rather',
#  'driven',
#  'static',
#  'database',
#  'recent',
#  'chatbots',
#  'also',
#  'combine',
#  'realtime',
#  'learning',
#  'evolutionary',
#  'algorithms',
#  'optimise',
#  'ability',
#  'communicate',
#  'based',
#  'conversation',
#  'held',
#  'still',
#  'currently',
#  'general',
#  'purpose',
#  'conversational',
#  'artificial',
#  'intelligence',
#  'software',
#  'developers',
#  'focus',
#  'practical',
#  'aspect',
#  'information',
#  'retrieval',
#  'chatbot',
#  'competitions',
#  'focus',
#  'turing',
#  'test',
#  'specific',
#  'goals',
#  'two',
#  'annual',
#  'contests',
#  'loebner',
#  'prize',
#  'chatterbox',
#  'challenge',
#  'offline',
#  'since',
#  '2015',
#  'materials',
#  'still',
#  'found',
#  'web',
#  'archives',
#  'according',
#  'forrester',
#  '2015',
#  'ai',
#  'replace',
#  '16',
#  'percent',
#  'american',
#  'jobs',
#  'end',
#  'decadechatbots',
#  'used',
#  'applications',
#  'customer',
#  'service',
#  'sales',
#  'product',
#  'education',
#  'however',
#  'study',
#  'conducted',
#  'narrative',
#  'science',
#  '2015',
#  'found',
#  '80',
#  'percent',
#  'respondents',
#  'believe',
#  'ai',
#  'improves',
#  'worker',
#  'performance',
#  'creates',
#  'jobs',
#  'citation',
#  'needed',
#  'application',
#  'see',
#  'also',
#  'virtual',
#  'assistant',
#  'aeromexico',
#  'airline',
#  'chatbot',
#  'running',
#  'facebook',
#  'messenger',
#  'march',
#  '2018',
#  'messaging',
#  'apps',
#  'many',
#  'companies',
#  'chatbots',
#  'run',
#  'messaging',
#  'apps',
#  'like',
#  'facebook',
#  'messenger',
#  'since',
#  '2016',
#  'wechat',
#  'since',
#  '2013',
#  'whatsapp',
#  'livechat',
#  'kik',
#  'slack',
#  'line',
#  'telegram',
#  'simply',
#  'via',
#  'sms',
#  'used',
#  'b2c',
#  'customer',
#  'service',
#  'sales',
#  'marketing',
#  '2016',
#  'facebook',
#  'messenger',
#  'allowed',
#  'developers',
#  'place',
#  'chatbots',
#  'platform',
#  '30000',
#  'bots',
#  'created',
#  'messenger',
#  'first',
#  'six',
#  'months',
#  'rising',
#  '100000',
#  'september',
#  '2017',
#  'since',
#  'september',
#  '2017',
#  'also',
#  'part',
#  'pilot',
#  'program',
#  'whatsapp',
#  'airlines',
#  'klm',
#  'aeromxico',
#  'announced',
#  'participation',
#  'testing',
#  'airlines',
#  'previously',
#  'launched',
#  'customer',
#  'services',
#  'facebook',
#  'messenger',
#  'platform',
#  'bots',
#  'usually',
#  'appear',
#  'one',
#  'user',
#  'contacts',
#  'sometimes',
#  'act',
#  'participants',
#  'group',
#  'chat',
#  'many',
#  'banks',
#  'insurers',
#  'media',
#  'ecommerce',
#  'companies',
#  'airlines',
#  'hotel',
#  'chains',
#  'retailers',
#  'health',
#  'care',
#  'providers',
#  'government',
#  'entities',
#  'restaurant',
#  'chains',
#  'used',
#  'chatbots',
#  'answer',
#  'simple',
#  'questions',
#  'increase',
#  'customer',
#  'engagement',
#  'promotion',
#  'offer',
#  'additional',
#  'ways',
#  'order',
#  '2017',
#  'study',
#  'showed',
#  '4',
#  'companies',
#  'used',
#  'chatbotsaccording',
#  '2016',
#  'study',
#  '80',
#  'businesses',
#  'said',
#  'intended',
#  'one',
#  '2020',
#  'part',
#  'company',
#  'apps',
#  'websites',
#  'previous',
#  'generations',
#  'chatbots',
#  'present',
#  'company',
#  'websites',
#  'eg',
#  'ask',
#  'jenn',
#  'alaska',
#  'airlines',
#  'debuted',
#  '2008',
#  'expedia',
#  'virtual',
#  'customer',
#  'service',
#  'agent',
#  'launched',
#  '2011the',
#  'newer',
#  'generation',
#  'chatbots',
#  'includes',
#  'ibm',
#  'watsonpowered',
#  'rocky',
#  'introduced',
#  'february',
#  '2017',
#  'new',
#  'york',
#  'citybased',
#  'ecommerce',
#  'company',
#  'rare',
#  'carat',
#  'provide',
#  'information',
#  'prospective',
#  'diamond',
#  'buyers',
#  'company',
#  'internal',
#  'platforms',
#  'companies',
#  'explore',
#  'ways',
#  'use',
#  'chatbots',
#  'internally',
#  'example',
#  'customer',
#  'support',
#  'human',
#  'resources',
#  'even',
#  'internetofthings',
#  'iot',
#  'projects',
#  'overstockcom',
#  'one',
#  'reportedly',
#  'launched',
#  'chatbot',
#  'named',
#  'mila',
#  'automate',
#  'certain',
#  'simple',
#  'yet',
#  'timeconsuming',
#  'processes',
#  'requesting',
#  'sick',
#  'leaveother',
#  'large',
#  'companies',
#  'lloyds',
#  'banking',
#  'group',
#  'royal',
#  'bank',
#  'scotland',
#  'renault',
#  'citron',
#  'using',
#  'automated',
#  'online',
#  'assistants',
#  'instead',
#  'call',
#  'centres',
#  'humans',
#  'provide',
#  'first',
#  'point',
#  'contact',
#  'saas',
#  'chatbot',
#  'business',
#  'ecosystem',
#  'steadily',
#  'growing',
#  'since',
#  'f8',
#  'conference',
#  'zuckerberg',
#  'unveiled',
#  'messenger',
#  'would',
#  'allow',
#  'chatbots',
#  'app',
#  'toys',
#  'chatbots',
#  'also',
#  'incorporated',
#  'devices',
#  'primarily',
#  'meant',
#  'computing',
#  'toys',
#  'hello',
#  'barbie',
#  'internetconnected',
#  'version',
#  'doll',
#  'uses',
#  'chatbot',
#  'provided',
#  'company',
#  'toytalk',
#  'previously',
#  'used',
#  'chatbot',
#  'range',
#  'smartphonebased',
#  'characters',
#  'childrenthese',
#  'characters',
#  'behaviors',
#  'constrained',
#  'set',
#  'rules',
#  'effect',
#  'emulate',
#  'particular',
#  'character',
#  'produce',
#  'storyline',
#  'ibm',
#  'watson',
#  'computer',
#  'used',
#  'basis',
#  'chatbotbased',
#  'educational',
#  'toys',
#  'companies',
#  'cognitoys',
#  'intended',
#  'interact',
#  'children',
#  'educational',
#  'purposes',
#  'chatbot',
#  'creation',
#  'process',
#  'creating',
#  'chatbot',
#  'follows',
#  'pattern',
#  'similar',
#  'development',
#  'web',
#  'page',
#  'mobile',
#  'app',
#  'divided',
#  'design',
#  'building',
#  'analytics',
#  'maintenance',
#  'design',
#  'chatbot',
#  'design',
#  'process',
#  'defines',
#  'interaction',
#  'user',
#  'chatbotthe',
#  'chatbot',
#  'designer',
#  'define',
#  'chatbot',
#  'personality',
#  'questions',
#  'asked',
#  'users',
#  'overall',
#  'interactionit',
#  'viewed',
#  'subset',
#  'conversational',
#  'design',
#  'order',
#  'speed',
#  'process',
#  'designers',
#  'use',
#  'dedicated',
#  'chatbot',
#  'design',
#  'tools',
#  'allow',
#  'immediate',
#  'preview',
#  'team',
#  'collaboration',
#  'video',
#  'exportan',
#  'important',
#  'part',
#  'chatbot',
#  'design',
#  'also',
#  'centered',
#  'around',
#  'user',
#  'testing',
#  'user',
#  'testing',
#  ...]

# %% [markdown]
# STEMMING
# Stemming is the process of finding similarities between words with the same root words. Stemming acts on words without knowing the context. Therefore, it’s faster but doesn’t always yield the desired result.

# %%
from nltk.stem import PorterStemmer

# %%
stemmer = PorterStemmer()

stemmed_data = [stemmer.stem(word) for word in clean_data_1]

stemmed_data
# Out:
# ['chatbot',
#  'also',
#  'known',
#  'talkbot',
#  'chatterbot',
#  'bot',
#  'im',
#  'bot',
#  'interact',
#  'agent',
#  'artifici',
#  'convers',
#  'entiti',
#  'comput',
#  'program',
#  'artifici',
#  'intellig',
#  'conduct',
#  'convers',
#  'via',
#  'auditori',
#  'textual',
#  'method',
#  'program',
#  'often',
#  'design',
#  'convincingli',
#  'simul',
#  'human',
#  'would',
#  'behav',
#  'convers',
#  'partner',
#  'therebi',
#  'pass',
#  'ture',
#  'test',
#  'chatbot',
#  'typic',
#  'use',
#  'dialog',
#  'system',
#  'variou',
#  'practic',
#  'purpos',
#  'includ',
#  'custom',
#  'servic',
#  'inform',
#  'acquisit',
#  'chatterbot',
#  'use',
#  'sophist',
#  'natur',
#  'languag',
#  'process',
#  'system',
#  'mani',
#  'simpler',
#  'system',
#  'scan',
#  'keyword',
#  'within',
#  'input',
#  'pull',
#  'repli',
#  'match',
#  'keyword',
#  'similar',
#  'word',
#  'pattern',
#  'databas',
#  'term',
#  'chatterbot',
#  'origin',
#  'coin',
#  'michael',
#  'mauldin',
#  'creator',
#  'first',
#  'verbot',
#  'julia',
#  '1994',
#  'describ',
#  'convers',
#  'programstoday',
#  'chatbot',
#  'either',
#  'access',
#  'via',
#  'virtual',
#  'assist',
#  'googl',
#  'assist',
#  'amazon',
#  'alexa',
#  'via',
#  'messag',
#  'app',
#  'facebook',
#  'messeng',
#  'wechat',
#  'via',
#  'individu',
#  'organ',
#  'app',
#  'websit',
#  'chatbot',
#  'classifi',
#  'usag',
#  'categori',
#  'convers',
#  'commerc',
#  'ecommerc',
#  'via',
#  'chat',
#  'analyt',
#  'commun',
#  'custom',
#  'support',
#  'design',
#  'develop',
#  'tool',
#  'educ',
#  'entertain',
#  'financ',
#  'food',
#  'game',
#  'health',
#  'hr',
#  'market',
#  'news',
#  'person',
#  'product',
#  'shop',
#  'social',
#  'sport',
#  'travel',
#  'util',
#  'background',
#  '1950',
#  'alan',
#  'ture',
#  'famou',
#  'articl',
#  'comput',
#  'machineri',
#  'intellig',
#  'publish',
#  'propos',
#  'call',
#  'ture',
#  'test',
#  'criterion',
#  'intellig',
#  'criterion',
#  'depend',
#  'abil',
#  'comput',
#  'program',
#  'imperson',
#  'human',
#  'realtim',
#  'written',
#  'convers',
#  'human',
#  'judg',
#  'suffici',
#  'well',
#  'judg',
#  'unabl',
#  'distinguish',
#  'reliablyon',
#  'basi',
#  'convers',
#  'content',
#  'alonebetween',
#  'program',
#  'real',
#  'human',
#  'notorieti',
#  'ture',
#  'propos',
#  'test',
#  'stimul',
#  'great',
#  'interest',
#  'joseph',
#  'weizenbaum',
#  'program',
#  'eliza',
#  'publish',
#  '1966',
#  'seem',
#  'abl',
#  'fool',
#  'user',
#  'believ',
#  'convers',
#  'real',
#  'human',
#  'howev',
#  'weizenbaum',
#  'claim',
#  'eliza',
#  'genuin',
#  'intellig',
#  'introduct',
#  'paper',
#  'present',
#  'debunk',
#  'exercis',
#  'artifici',
#  'intellig',
#  'machin',
#  'made',
#  'behav',
#  'wondrou',
#  'way',
#  'often',
#  'suffici',
#  'dazzl',
#  'even',
#  'experienc',
#  'observ',
#  'particular',
#  'program',
#  'unmask',
#  'inner',
#  'work',
#  'explain',
#  'magic',
#  'crumbl',
#  'away',
#  'stand',
#  'reveal',
#  'mere',
#  'collect',
#  'procedur',
#  'observ',
#  'say',
#  'could',
#  'written',
#  'thought',
#  'move',
#  'program',
#  'question',
#  'shelf',
#  'mark',
#  'intellig',
#  'reserv',
#  'curio',
#  'object',
#  'paper',
#  'caus',
#  'reevalu',
#  'program',
#  'explain',
#  'program',
#  'ever',
#  'need',
#  'eliza',
#  'key',
#  'method',
#  'oper',
#  'copi',
#  'chatbot',
#  'design',
#  'ever',
#  'sinc',
#  'involv',
#  'recognit',
#  'cue',
#  'word',
#  'phrase',
#  'input',
#  'output',
#  'correspond',
#  'preprepar',
#  'preprogram',
#  'respons',
#  'move',
#  'convers',
#  'forward',
#  'appar',
#  'meaning',
#  'way',
#  'eg',
#  'respond',
#  'input',
#  'contain',
#  'word',
#  'mother',
#  'tell',
#  'famili',
#  'thu',
#  'illus',
#  'understand',
#  'gener',
#  'even',
#  'though',
#  'process',
#  'involv',
#  'mere',
#  'superfici',
#  'eliza',
#  'show',
#  'illus',
#  'surprisingli',
#  'easi',
#  'gener',
#  'human',
#  'judg',
#  'readi',
#  'give',
#  'benefit',
#  'doubt',
#  'convers',
#  'respons',
#  'capabl',
#  'interpret',
#  'intellig',
#  'interfac',
#  'design',
#  'come',
#  'appreci',
#  'human',
#  'readi',
#  'interpret',
#  'comput',
#  'output',
#  'genuin',
#  'conversationaleven',
#  'actual',
#  'base',
#  'rather',
#  'simpl',
#  'patternmatchingcan',
#  'exploit',
#  'use',
#  'purpos',
#  'peopl',
#  'prefer',
#  'engag',
#  'program',
#  'humanlik',
#  'give',
#  'chatbotstyl',
#  'techniqu',
#  'potenti',
#  'use',
#  'role',
#  'interact',
#  'system',
#  'need',
#  'elicit',
#  'inform',
#  'user',
#  'long',
#  'inform',
#  'rel',
#  'straightforward',
#  'fall',
#  'predict',
#  'categori',
#  'thu',
#  'exampl',
#  'onlin',
#  'help',
#  'system',
#  'use',
#  'employ',
#  'chatbot',
#  'techniqu',
#  'identifi',
#  'area',
#  'help',
#  'user',
#  'requir',
#  'potenti',
#  'provid',
#  'friendlier',
#  'interfac',
#  'formal',
#  'search',
#  'menu',
#  'system',
#  'sort',
#  'usag',
#  'hold',
#  'prospect',
#  'move',
#  'chatbot',
#  'technolog',
#  'weizenbaum',
#  'shelf',
#  'reserv',
#  'curio',
#  'mark',
#  'genuin',
#  'use',
#  'comput',
#  'method',
#  'develop',
#  'classic',
#  'histor',
#  'earli',
#  'chatbot',
#  'eliza',
#  '1966',
#  'parri',
#  '1972',
#  'recent',
#  'notabl',
#  'program',
#  'includ',
#  'alic',
#  'jabberwacki',
#  'dude',
#  'agenc',
#  'national',
#  'de',
#  'la',
#  'recherch',
#  'cnr',
#  '2006',
#  'eliza',
#  'parri',
#  'use',
#  'exclus',
#  'simul',
#  'type',
#  'convers',
#  'mani',
#  'chatbot',
#  'includ',
#  'function',
#  'featur',
#  'game',
#  'web',
#  'search',
#  'abil',
#  '1984',
#  'book',
#  'call',
#  'policeman',
#  'beard',
#  'half',
#  'construct',
#  'publish',
#  'allegedli',
#  'written',
#  'chatbot',
#  'racter',
#  'though',
#  'program',
#  'releas',
#  'would',
#  'capabl',
#  'one',
#  'pertin',
#  'field',
#  'ai',
#  'research',
#  'natur',
#  'languag',
#  'process',
#  'usual',
#  'weak',
#  'ai',
#  'field',
#  'employ',
#  'special',
#  'softwar',
#  'program',
#  'languag',
#  'creat',
#  'specif',
#  'narrow',
#  'function',
#  'requir',
#  'exampl',
#  'alic',
#  'use',
#  'markup',
#  'languag',
#  'call',
#  'aiml',
#  'specif',
#  'function',
#  'convers',
#  'agent',
#  'sinc',
#  'adopt',
#  'variou',
#  'develop',
#  'call',
#  'alicebot',
#  'nevertheless',
#  'alic',
#  'still',
#  'pure',
#  'base',
#  'pattern',
#  'match',
#  'techniqu',
#  'without',
#  'reason',
#  'capabl',
#  'techniqu',
#  'eliza',
#  'use',
#  'back',
#  '1966',
#  'strong',
#  'ai',
#  'would',
#  'requir',
#  'sapienc',
#  'logic',
#  'reason',
#  'abil',
#  'jabberwacki',
#  'learn',
#  'new',
#  'respons',
#  'context',
#  'base',
#  'realtim',
#  'user',
#  'interact',
#  'rather',
#  'driven',
#  'static',
#  'databas',
#  'recent',
#  'chatbot',
#  'also',
#  'combin',
#  'realtim',
#  'learn',
#  'evolutionari',
#  'algorithm',
#  'optimis',
#  'abil',
#  'commun',
#  'base',
#  'convers',
#  'held',
#  'still',
#  'current',
#  'gener',
#  'purpos',
#  'convers',
#  'artifici',
#  'intellig',
#  'softwar',
#  'develop',
#  'focu',
#  'practic',
#  'aspect',
#  'inform',
#  'retriev',
#  'chatbot',
#  'competit',
#  'focu',
#  'ture',
#  'test',
#  'specif',
#  'goal',
#  'two',
#  'annual',
#  'contest',
#  'loebner',
#  'prize',
#  'chatterbox',
#  'challeng',
#  'offlin',
#  'sinc',
#  '2015',
#  'materi',
#  'still',
#  'found',
#  'web',
#  'archiv',
#  'accord',
#  'forrest',
#  '2015',
#  'ai',
#  'replac',
#  '16',
#  'percent',
#  'american',
#  'job',
#  'end',
#  'decadechatbot',
#  'use',
#  'applic',
#  'custom',
#  'servic',
#  'sale',
#  'product',
#  'educ',
#  'howev',
#  'studi',
#  'conduct',
#  'narr',
#  'scienc',
#  '2015',
#  'found',
#  '80',
#  'percent',
#  'respond',
#  'believ',
#  'ai',
#  'improv',
#  'worker',
#  'perform',
#  'creat',
#  'job',
#  'citat',
#  'need',
#  'applic',
#  'see',
#  'also',
#  'virtual',
#  'assist',
#  'aeromexico',
#  'airlin',
#  'chatbot',
#  'run',
#  'facebook',
#  'messeng',
#  'march',
#  '2018',
#  'messag',
#  'app',
#  'mani',
#  'compani',
#  'chatbot',
#  'run',
#  'messag',
#  'app',
#  'like',
#  'facebook',
#  'messeng',
#  'sinc',
#  '2016',
#  'wechat',
#  'sinc',
#  '2013',
#  'whatsapp',
#  'livechat',
#  'kik',
#  'slack',
#  'line',
#  'telegram',
#  'simpli',
#  'via',
#  'sm',
#  'use',
#  'b2c',
#  'custom',
#  'servic',
#  'sale',
#  'market',
#  '2016',
#  'facebook',
#  'messeng',
#  'allow',
#  'develop',
#  'place',
#  'chatbot',
#  'platform',
#  '30000',
#  'bot',
#  'creat',
#  'messeng',
#  'first',
#  'six',
#  'month',
#  'rise',
#  '100000',
#  'septemb',
#  '2017',
#  'sinc',
#  'septemb',
#  '2017',
#  'also',
#  'part',
#  'pilot',
#  'program',
#  'whatsapp',
#  'airlin',
#  'klm',
#  'aeromxico',
#  'announc',
#  'particip',
#  'test',
#  'airlin',
#  'previous',
#  'launch',
#  'custom',
#  'servic',
#  'facebook',
#  'messeng',
#  'platform',
#  'bot',
#  'usual',
#  'appear',
#  'one',
#  'user',
#  'contact',
#  'sometim',
#  'act',
#  'particip',
#  'group',
#  'chat',
#  'mani',
#  'bank',
#  'insur',
#  'media',
#  'ecommerc',
#  'compani',
#  'airlin',
#  'hotel',
#  'chain',
#  'retail',
#  'health',
#  'care',
#  'provid',
#  'govern',
#  'entiti',
#  'restaur',
#  'chain',
#  'use',
#  'chatbot',
#  'answer',
#  'simpl',
#  'question',
#  'increas',
#  'custom',
#  'engag',
#  'promot',
#  'offer',
#  'addit',
#  'way',
#  'order',
#  '2017',
#  'studi',
#  'show',
#  '4',
#  'compani',
#  'use',
#  'chatbotsaccord',
#  '2016',
#  'studi',
#  '80',
#  'busi',
#  'said',
#  'intend',
#  'one',
#  '2020',
#  'part',
#  'compani',
#  'app',
#  'websit',
#  'previou',
#  'gener',
#  'chatbot',
#  'present',
#  'compani',
#  'websit',
#  'eg',
#  'ask',
#  'jenn',
#  'alaska',
#  'airlin',
#  'debut',
#  '2008',
#  'expedia',
#  'virtual',
#  'custom',
#  'servic',
#  'agent',
#  'launch',
#  '2011the',
#  'newer',
#  'gener',
#  'chatbot',
#  'includ',
#  'ibm',
#  'watsonpow',
#  'rocki',
#  'introduc',
#  'februari',
#  '2017',
#  'new',
#  'york',
#  'citybas',
#  'ecommerc',
#  'compani',
#  'rare',
#  'carat',
#  'provid',
#  'inform',
#  'prospect',
#  'diamond',
#  'buyer',
#  'compani',
#  'intern',
#  'platform',
#  'compani',
#  'explor',
#  'way',
#  'use',
#  'chatbot',
#  'intern',
#  'exampl',
#  'custom',
#  'support',
#  'human',
#  'resourc',
#  'even',
#  'internetofth',
#  'iot',
#  'project',
#  'overstockcom',
#  'one',
#  'reportedli',
#  'launch',
#  'chatbot',
#  'name',
#  'mila',
#  'autom',
#  'certain',
#  'simpl',
#  'yet',
#  'timeconsum',
#  'process',
#  'request',
#  'sick',
#  'leaveoth',
#  'larg',
#  'compani',
#  'lloyd',
#  'bank',
#  'group',
#  'royal',
#  'bank',
#  'scotland',
#  'renault',
#  'citron',
#  'use',
#  'autom',
#  'onlin',
#  'assist',
#  'instead',
#  'call',
#  'centr',
#  'human',
#  'provid',
#  'first',
#  'point',
#  'contact',
#  'saa',
#  'chatbot',
#  'busi',
#  'ecosystem',
#  'steadili',
#  'grow',
#  'sinc',
#  'f8',
#  'confer',
#  'zuckerberg',
#  'unveil',
#  'messeng',
#  'would',
#  'allow',
#  'chatbot',
#  'app',
#  'toy',
#  'chatbot',
#  'also',
#  'incorpor',
#  'devic',
#  'primarili',
#  'meant',
#  'comput',
#  'toy',
#  'hello',
#  'barbi',
#  'internetconnect',
#  'version',
#  'doll',
#  'use',
#  'chatbot',
#  'provid',
#  'compani',
#  'toytalk',
#  'previous',
#  'use',
#  'chatbot',
#  'rang',
#  'smartphonebas',
#  'charact',
#  'childrenthes',
#  'charact',
#  'behavior',
#  'constrain',
#  'set',
#  'rule',
#  'effect',
#  'emul',
#  'particular',
#  'charact',
#  'produc',
#  'storylin',
#  'ibm',
#  'watson',
#  'comput',
#  'use',
#  'basi',
#  'chatbotbas',
#  'educ',
#  'toy',
#  'compani',
#  'cognitoy',
#  'intend',
#  'interact',
#  'children',
#  'educ',
#  'purpos',
#  'chatbot',
#  'creation',
#  'process',
#  'creat',
#  'chatbot',
#  'follow',
#  'pattern',
#  'similar',
#  'develop',
#  'web',
#  'page',
#  'mobil',
#  'app',
#  'divid',
#  'design',
#  'build',
#  'analyt',
#  'mainten',
#  'design',
#  'chatbot',
#  'design',
#  'process',
#  'defin',
#  'interact',
#  'user',
#  'chatbotth',
#  'chatbot',
#  'design',
#  'defin',
#  'chatbot',
#  'person',
#  'question',
#  'ask',
#  'user',
#  'overal',
#  'interactionit',
#  'view',
#  'subset',
#  'convers',
#  'design',
#  'order',
#  'speed',
#  'process',
#  'design',
#  'use',
#  'dedic',
#  'chatbot',
#  'design',
#  'tool',
#  'allow',
#  'immedi',
#  'preview',
#  'team',
#  'collabor',
#  'video',
#  'exportan',
#  'import',
#  'part',
#  'chatbot',
#  'design',
#  'also',
#  'center',
#  'around',
#  'user',
#  'test',
#  'user',
#  'test',
#  ...]

# %% [markdown]
# LEMMATIZATION
# Lemmatization is the process of grouping together different infected forms of a word, called lemma. The output of lemmatization is a proper word. It uses a lexical vocabulary to derive the root form, is more time-consuming than stemming, and is most likely to yield accurate results. It uses a lexical database called WordNet.

# %%
from nltk.stem.wordnet import WordNetLemmatizer

# %%
import nltk
lemmer = nltk.stem.WordNetLemmatizer()
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
lemm_data = []
for word in clean_data_1:
   lemm_data.append(lemmer.lemmatize(word))

# %%
lemm_data
# Out:
# ['chatbot',
#  'also',
#  'known',
#  'talkbot',
#  'chatterbot',
#  'bot',
#  'im',
#  'bot',
#  'interactive',
#  'agent',
#  'artificial',
#  'conversational',
#  'entity',
#  'computer',
#  'program',
#  'artificial',
#  'intelligence',
#  'conduct',
#  'conversation',
#  'via',
#  'auditory',
#  'textual',
#  'method',
#  'program',
#  'often',
#  'designed',
#  'convincingly',
#  'simulate',
#  'human',
#  'would',
#  'behave',
#  'conversational',
#  'partner',
#  'thereby',
#  'passing',
#  'turing',
#  'test',
#  'chatbots',
#  'typically',
#  'used',
#  'dialog',
#  'system',
#  'various',
#  'practical',
#  'purpose',
#  'including',
#  'customer',
#  'service',
#  'information',
#  'acquisition',
#  'chatterbots',
#  'use',
#  'sophisticated',
#  'natural',
#  'language',
#  'processing',
#  'system',
#  'many',
#  'simpler',
#  'system',
#  'scan',
#  'keywords',
#  'within',
#  'input',
#  'pull',
#  'reply',
#  'matching',
#  'keywords',
#  'similar',
#  'wording',
#  'pattern',
#  'database',
#  'term',
#  'chatterbot',
#  'originally',
#  'coined',
#  'michael',
#  'mauldin',
#  'creator',
#  'first',
#  'verbot',
#  'julia',
#  '1994',
#  'describe',
#  'conversational',
#  'programstoday',
#  'chatbots',
#  'either',
#  'accessed',
#  'via',
#  'virtual',
#  'assistant',
#  'google',
#  'assistant',
#  'amazon',
#  'alexa',
#  'via',
#  'messaging',
#  'apps',
#  'facebook',
#  'messenger',
#  'wechat',
#  'via',
#  'individual',
#  'organization',
#  'apps',
#  'website',
#  'chatbots',
#  'classified',
#  'usage',
#  'category',
#  'conversational',
#  'commerce',
#  'ecommerce',
#  'via',
#  'chat',
#  'analytics',
#  'communication',
#  'customer',
#  'support',
#  'design',
#  'developer',
#  'tool',
#  'education',
#  'entertainment',
#  'finance',
#  'food',
#  'game',
#  'health',
#  'hr',
#  'marketing',
#  'news',
#  'personal',
#  'productivity',
#  'shopping',
#  'social',
#  'sport',
#  'travel',
#  'utility',
#  'background',
#  '1950',
#  'alan',
#  'turing',
#  'famous',
#  'article',
#  'computing',
#  'machinery',
#  'intelligence',
#  'published',
#  'proposed',
#  'called',
#  'turing',
#  'test',
#  'criterion',
#  'intelligence',
#  'criterion',
#  'depends',
#  'ability',
#  'computer',
#  'program',
#  'impersonate',
#  'human',
#  'realtime',
#  'written',
#  'conversation',
#  'human',
#  'judge',
#  'sufficiently',
#  'well',
#  'judge',
#  'unable',
#  'distinguish',
#  'reliablyon',
#  'basis',
#  'conversational',
#  'content',
#  'alonebetween',
#  'program',
#  'real',
#  'human',
#  'notoriety',
#  'turing',
#  'proposed',
#  'test',
#  'stimulated',
#  'great',
#  'interest',
#  'joseph',
#  'weizenbaum',
#  'program',
#  'eliza',
#  'published',
#  '1966',
#  'seemed',
#  'able',
#  'fool',
#  'user',
#  'believing',
#  'conversing',
#  'real',
#  'human',
#  'however',
#  'weizenbaum',
#  'claim',
#  'eliza',
#  'genuinely',
#  'intelligent',
#  'introduction',
#  'paper',
#  'presented',
#  'debunking',
#  'exercise',
#  'artificial',
#  'intelligence',
#  'machine',
#  'made',
#  'behave',
#  'wondrous',
#  'way',
#  'often',
#  'sufficient',
#  'dazzle',
#  'even',
#  'experienced',
#  'observer',
#  'particular',
#  'program',
#  'unmasked',
#  'inner',
#  'working',
#  'explained',
#  'magic',
#  'crumbles',
#  'away',
#  'stand',
#  'revealed',
#  'mere',
#  'collection',
#  'procedure',
#  'observer',
#  'say',
#  'could',
#  'written',
#  'thought',
#  'move',
#  'program',
#  'question',
#  'shelf',
#  'marked',
#  'intelligent',
#  'reserved',
#  'curio',
#  'object',
#  'paper',
#  'cause',
#  'reevaluation',
#  'program',
#  'explained',
#  'program',
#  'ever',
#  'needed',
#  'eliza',
#  'key',
#  'method',
#  'operation',
#  'copied',
#  'chatbot',
#  'designer',
#  'ever',
#  'since',
#  'involves',
#  'recognition',
#  'cue',
#  'word',
#  'phrase',
#  'input',
#  'output',
#  'corresponding',
#  'preprepared',
#  'preprogrammed',
#  'response',
#  'move',
#  'conversation',
#  'forward',
#  'apparently',
#  'meaningful',
#  'way',
#  'eg',
#  'responding',
#  'input',
#  'contains',
#  'word',
#  'mother',
#  'tell',
#  'family',
#  'thus',
#  'illusion',
#  'understanding',
#  'generated',
#  'even',
#  'though',
#  'processing',
#  'involved',
#  'merely',
#  'superficial',
#  'eliza',
#  'showed',
#  'illusion',
#  'surprisingly',
#  'easy',
#  'generate',
#  'human',
#  'judge',
#  'ready',
#  'give',
#  'benefit',
#  'doubt',
#  'conversational',
#  'response',
#  'capable',
#  'interpreted',
#  'intelligent',
#  'interface',
#  'designer',
#  'come',
#  'appreciate',
#  'human',
#  'readiness',
#  'interpret',
#  'computer',
#  'output',
#  'genuinely',
#  'conversationaleven',
#  'actually',
#  'based',
#  'rather',
#  'simple',
#  'patternmatchingcan',
#  'exploited',
#  'useful',
#  'purpose',
#  'people',
#  'prefer',
#  'engage',
#  'program',
#  'humanlike',
#  'give',
#  'chatbotstyle',
#  'technique',
#  'potentially',
#  'useful',
#  'role',
#  'interactive',
#  'system',
#  'need',
#  'elicit',
#  'information',
#  'user',
#  'long',
#  'information',
#  'relatively',
#  'straightforward',
#  'fall',
#  'predictable',
#  'category',
#  'thus',
#  'example',
#  'online',
#  'help',
#  'system',
#  'usefully',
#  'employ',
#  'chatbot',
#  'technique',
#  'identify',
#  'area',
#  'help',
#  'user',
#  'require',
#  'potentially',
#  'providing',
#  'friendlier',
#  'interface',
#  'formal',
#  'search',
#  'menu',
#  'system',
#  'sort',
#  'usage',
#  'hold',
#  'prospect',
#  'moving',
#  'chatbot',
#  'technology',
#  'weizenbaum',
#  'shelf',
#  'reserved',
#  'curio',
#  'marked',
#  'genuinely',
#  'useful',
#  'computational',
#  'method',
#  'development',
#  'classic',
#  'historic',
#  'early',
#  'chatbots',
#  'eliza',
#  '1966',
#  'parry',
#  '1972',
#  'recent',
#  'notable',
#  'program',
#  'include',
#  'alice',
#  'jabberwacky',
#  'dude',
#  'agence',
#  'nationale',
#  'de',
#  'la',
#  'recherche',
#  'cnrs',
#  '2006',
#  'eliza',
#  'parry',
#  'used',
#  'exclusively',
#  'simulate',
#  'typed',
#  'conversation',
#  'many',
#  'chatbots',
#  'include',
#  'functional',
#  'feature',
#  'game',
#  'web',
#  'searching',
#  'ability',
#  '1984',
#  'book',
#  'called',
#  'policeman',
#  'beard',
#  'half',
#  'constructed',
#  'published',
#  'allegedly',
#  'written',
#  'chatbot',
#  'racter',
#  'though',
#  'program',
#  'released',
#  'would',
#  'capable',
#  'one',
#  'pertinent',
#  'field',
#  'ai',
#  'research',
#  'natural',
#  'language',
#  'processing',
#  'usually',
#  'weak',
#  'ai',
#  'field',
#  'employ',
#  'specialized',
#  'software',
#  'programming',
#  'language',
#  'created',
#  'specifically',
#  'narrow',
#  'function',
#  'required',
#  'example',
#  'alice',
#  'us',
#  'markup',
#  'language',
#  'called',
#  'aiml',
#  'specific',
#  'function',
#  'conversational',
#  'agent',
#  'since',
#  'adopted',
#  'various',
#  'developer',
#  'called',
#  'alicebots',
#  'nevertheless',
#  'alice',
#  'still',
#  'purely',
#  'based',
#  'pattern',
#  'matching',
#  'technique',
#  'without',
#  'reasoning',
#  'capability',
#  'technique',
#  'eliza',
#  'using',
#  'back',
#  '1966',
#  'strong',
#  'ai',
#  'would',
#  'require',
#  'sapience',
#  'logical',
#  'reasoning',
#  'ability',
#  'jabberwacky',
#  'learns',
#  'new',
#  'response',
#  'context',
#  'based',
#  'realtime',
#  'user',
#  'interaction',
#  'rather',
#  'driven',
#  'static',
#  'database',
#  'recent',
#  'chatbots',
#  'also',
#  'combine',
#  'realtime',
#  'learning',
#  'evolutionary',
#  'algorithm',
#  'optimise',
#  'ability',
#  'communicate',
#  'based',
#  'conversation',
#  'held',
#  'still',
#  'currently',
#  'general',
#  'purpose',
#  'conversational',
#  'artificial',
#  'intelligence',
#  'software',
#  'developer',
#  'focus',
#  'practical',
#  'aspect',
#  'information',
#  'retrieval',
#  'chatbot',
#  'competition',
#  'focus',
#  'turing',
#  'test',
#  'specific',
#  'goal',
#  'two',
#  'annual',
#  'contest',
#  'loebner',
#  'prize',
#  'chatterbox',
#  'challenge',
#  'offline',
#  'since',
#  '2015',
#  'material',
#  'still',
#  'found',
#  'web',
#  'archive',
#  'according',
#  'forrester',
#  '2015',
#  'ai',
#  'replace',
#  '16',
#  'percent',
#  'american',
#  'job',
#  'end',
#  'decadechatbots',
#  'used',
#  'application',
#  'customer',
#  'service',
#  'sale',
#  'product',
#  'education',
#  'however',
#  'study',
#  'conducted',
#  'narrative',
#  'science',
#  '2015',
#  'found',
#  '80',
#  'percent',
#  'respondent',
#  'believe',
#  'ai',
#  'improves',
#  'worker',
#  'performance',
#  'creates',
#  'job',
#  'citation',
#  'needed',
#  'application',
#  'see',
#  'also',
#  'virtual',
#  'assistant',
#  'aeromexico',
#  'airline',
#  'chatbot',
#  'running',
#  'facebook',
#  'messenger',
#  'march',
#  '2018',
#  'messaging',
#  'apps',
#  'many',
#  'company',
#  'chatbots',
#  'run',
#  'messaging',
#  'apps',
#  'like',
#  'facebook',
#  'messenger',
#  'since',
#  '2016',
#  'wechat',
#  'since',
#  '2013',
#  'whatsapp',
#  'livechat',
#  'kik',
#  'slack',
#  'line',
#  'telegram',
#  'simply',
#  'via',
#  'sm',
#  'used',
#  'b2c',
#  'customer',
#  'service',
#  'sale',
#  'marketing',
#  '2016',
#  'facebook',
#  'messenger',
#  'allowed',
#  'developer',
#  'place',
#  'chatbots',
#  'platform',
#  '30000',
#  'bot',
#  'created',
#  'messenger',
#  'first',
#  'six',
#  'month',
#  'rising',
#  '100000',
#  'september',
#  '2017',
#  'since',
#  'september',
#  '2017',
#  'also',
#  'part',
#  'pilot',
#  'program',
#  'whatsapp',
#  'airline',
#  'klm',
#  'aeromxico',
#  'announced',
#  'participation',
#  'testing',
#  'airline',
#  'previously',
#  'launched',
#  'customer',
#  'service',
#  'facebook',
#  'messenger',
#  'platform',
#  'bot',
#  'usually',
#  'appear',
#  'one',
#  'user',
#  'contact',
#  'sometimes',
#  'act',
#  'participant',
#  'group',
#  'chat',
#  'many',
#  'bank',
#  'insurer',
#  'medium',
#  'ecommerce',
#  'company',
#  'airline',
#  'hotel',
#  'chain',
#  'retailer',
#  'health',
#  'care',
#  'provider',
#  'government',
#  'entity',
#  'restaurant',
#  'chain',
#  'used',
#  'chatbots',
#  'answer',
#  'simple',
#  'question',
#  'increase',
#  'customer',
#  'engagement',
#  'promotion',
#  'offer',
#  'additional',
#  'way',
#  'order',
#  '2017',
#  'study',
#  'showed',
#  '4',
#  'company',
#  'used',
#  'chatbotsaccording',
#  '2016',
#  'study',
#  '80',
#  'business',
#  'said',
#  'intended',
#  'one',
#  '2020',
#  'part',
#  'company',
#  'apps',
#  'website',
#  'previous',
#  'generation',
#  'chatbots',
#  'present',
#  'company',
#  'website',
#  'eg',
#  'ask',
#  'jenn',
#  'alaska',
#  'airline',
#  'debuted',
#  '2008',
#  'expedia',
#  'virtual',
#  'customer',
#  'service',
#  'agent',
#  'launched',
#  '2011the',
#  'newer',
#  'generation',
#  'chatbots',
#  'includes',
#  'ibm',
#  'watsonpowered',
#  'rocky',
#  'introduced',
#  'february',
#  '2017',
#  'new',
#  'york',
#  'citybased',
#  'ecommerce',
#  'company',
#  'rare',
#  'carat',
#  'provide',
#  'information',
#  'prospective',
#  'diamond',
#  'buyer',
#  'company',
#  'internal',
#  'platform',
#  'company',
#  'explore',
#  'way',
#  'use',
#  'chatbots',
#  'internally',
#  'example',
#  'customer',
#  'support',
#  'human',
#  'resource',
#  'even',
#  'internetofthings',
#  'iot',
#  'project',
#  'overstockcom',
#  'one',
#  'reportedly',
#  'launched',
#  'chatbot',
#  'named',
#  'mila',
#  'automate',
#  'certain',
#  'simple',
#  'yet',
#  'timeconsuming',
#  'process',
#  'requesting',
#  'sick',
#  'leaveother',
#  'large',
#  'company',
#  'lloyd',
#  'banking',
#  'group',
#  'royal',
#  'bank',
#  'scotland',
#  'renault',
#  'citron',
#  'using',
#  'automated',
#  'online',
#  'assistant',
#  'instead',
#  'call',
#  'centre',
#  'human',
#  'provide',
#  'first',
#  'point',
#  'contact',
#  'saas',
#  'chatbot',
#  'business',
#  'ecosystem',
#  'steadily',
#  'growing',
#  'since',
#  'f8',
#  'conference',
#  'zuckerberg',
#  'unveiled',
#  'messenger',
#  'would',
#  'allow',
#  'chatbots',
#  'app',
#  'toy',
#  'chatbots',
#  'also',
#  'incorporated',
#  'device',
#  'primarily',
#  'meant',
#  'computing',
#  'toy',
#  'hello',
#  'barbie',
#  'internetconnected',
#  'version',
#  'doll',
#  'us',
#  'chatbot',
#  'provided',
#  'company',
#  'toytalk',
#  'previously',
#  'used',
#  'chatbot',
#  'range',
#  'smartphonebased',
#  'character',
#  'childrenthese',
#  'character',
#  'behavior',
#  'constrained',
#  'set',
#  'rule',
#  'effect',
#  'emulate',
#  'particular',
#  'character',
#  'produce',
#  'storyline',
#  'ibm',
#  'watson',
#  'computer',
#  'used',
#  'basis',
#  'chatbotbased',
#  'educational',
#  'toy',
#  'company',
#  'cognitoys',
#  'intended',
#  'interact',
#  'child',
#  'educational',
#  'purpose',
#  'chatbot',
#  'creation',
#  'process',
#  'creating',
#  'chatbot',
#  'follows',
#  'pattern',
#  'similar',
#  'development',
#  'web',
#  'page',
#  'mobile',
#  'app',
#  'divided',
#  'design',
#  'building',
#  'analytics',
#  'maintenance',
#  'design',
#  'chatbot',
#  'design',
#  'process',
#  'defines',
#  'interaction',
#  'user',
#  'chatbotthe',
#  'chatbot',
#  'designer',
#  'define',
#  'chatbot',
#  'personality',
#  'question',
#  'asked',
#  'user',
#  'overall',
#  'interactionit',
#  'viewed',
#  'subset',
#  'conversational',
#  'design',
#  'order',
#  'speed',
#  'process',
#  'designer',
#  'use',
#  'dedicated',
#  'chatbot',
#  'design',
#  'tool',
#  'allow',
#  'immediate',
#  'preview',
#  'team',
#  'collaboration',
#  'video',
#  'exportan',
#  'important',
#  'part',
#  'chatbot',
#  'design',
#  'also',
#  'centered',
#  'around',
#  'user',
#  'testing',
#  'user',
#  'testing',
#  ...]

# %% [markdown]
# Usage of either stemming or lemmatization will depend on the situation. If speed is required, it’s better to resort to stemming, but if accuracy is required it’s best to use lemmatization.

# %% [markdown]
# PARTS OF SPEECH TAGGING
# In this process, the words in the text are assigned a label with corresponding parts of speech components such as nouns, verbs, adjectives, or adverbs. It takes features like the previous word, next word, and capitalization of the first word into consideration when assigning a POS tag to a word.

# %%
pos_data = nltk.pos_tag(lemm_data)
pos_data
# Out:
# [('chatbot', 'NN'),
#  ('also', 'RB'),
#  ('known', 'VBN'),
#  ('talkbot', 'NN'),
#  ('chatterbot', 'NN'),
#  ('bot', 'NN'),
#  ('im', 'NN'),
#  ('bot', 'NN'),
#  ('interactive', 'JJ'),
#  ('agent', 'NN'),
#  ('artificial', 'JJ'),
#  ('conversational', 'JJ'),
#  ('entity', 'NN'),
#  ('computer', 'NN'),
#  ('program', 'NN'),
#  ('artificial', 'JJ'),
#  ('intelligence', 'NN'),
#  ('conduct', 'NN'),
#  ('conversation', 'NN'),
#  ('via', 'IN'),
#  ('auditory', 'JJ'),
#  ('textual', 'JJ'),
#  ('method', 'NN'),
#  ('program', 'NN'),
#  ('often', 'RB'),
#  ('designed', 'VBN'),
#  ('convincingly', 'RB'),
#  ('simulate', 'JJ'),
#  ('human', 'NN'),
#  ('would', 'MD'),
#  ('behave', 'VB'),
#  ('conversational', 'JJ'),
#  ('partner', 'NN'),
#  ('thereby', 'RB'),
#  ('passing', 'VBG'),
#  ('turing', 'VBG'),
#  ('test', 'NN'),
#  ('chatbots', 'NNS'),
#  ('typically', 'RB'),
#  ('used', 'VBN'),
#  ('dialog', 'NN'),
#  ('system', 'NN'),
#  ('various', 'JJ'),
#  ('practical', 'JJ'),
#  ('purpose', 'NN'),
#  ('including', 'VBG'),
#  ('customer', 'NN'),
#  ('service', 'NN'),
#  ('information', 'NN'),
#  ('acquisition', 'NN'),
#  ('chatterbots', 'NNS'),
#  ('use', 'VBP'),
#  ('sophisticated', 'JJ'),
#  ('natural', 'JJ'),
#  ('language', 'NN'),
#  ('processing', 'NN'),
#  ('system', 'NN'),
#  ('many', 'JJ'),
#  ('simpler', 'NN'),
#  ('system', 'NN'),
#  ('scan', 'JJ'),
#  ('keywords', 'NNS'),
#  ('within', 'IN'),
#  ('input', 'NN'),
#  ('pull', 'VBP'),
#  ('reply', 'NN'),
#  ('matching', 'JJ'),
#  ('keywords', 'NNS'),
#  ('similar', 'JJ'),
#  ('wording', 'VBG'),
#  ('pattern', 'JJ'),
#  ('database', 'JJ'),
#  ('term', 'NN'),
#  ('chatterbot', 'NN'),
#  ('originally', 'RB'),
#  ('coined', 'VBD'),
#  ('michael', 'JJ'),
#  ('mauldin', 'NN'),
#  ('creator', 'NN'),
#  ('first', 'RB'),
#  ('verbot', 'VBZ'),
#  ('julia', 'NN'),
#  ('1994', 'CD'),
#  ('describe', 'NN'),
#  ('conversational', 'JJ'),
#  ('programstoday', 'NN'),
#  ('chatbots', 'NNS'),
#  ('either', 'CC'),
#  ('accessed', 'JJ'),
#  ('via', 'IN'),
#  ('virtual', 'JJ'),
#  ('assistant', 'NN'),
#  ('google', 'NN'),
#  ('assistant', 'NN'),
#  ('amazon', 'NN'),
#  ('alexa', 'NN'),
#  ('via', 'IN'),
#  ('messaging', 'VBG'),
#  ('apps', 'JJ'),
#  ('facebook', 'NN'),
#  ('messenger', 'NN'),
#  ('wechat', 'WP'),
#  ('via', 'IN'),
#  ('individual', 'JJ'),
#  ('organization', 'NN'),
#  ('apps', 'IN'),
#  ('website', 'JJ'),
#  ('chatbots', 'NNS'),
#  ('classified', 'VBN'),
#  ('usage', 'JJ'),
#  ('category', 'JJ'),
#  ('conversational', 'JJ'),
#  ('commerce', 'NN'),
#  ('ecommerce', 'NN'),
#  ('via', 'IN'),
#  ('chat', 'WP'),
#  ('analytics', 'NNS'),
#  ('communication', 'NN'),
#  ('customer', 'NN'),
#  ('support', 'NN'),
#  ('design', 'NN'),
#  ('developer', 'NN'),
#  ('tool', 'NN'),
#  ('education', 'NN'),
#  ('entertainment', 'NN'),
#  ('finance', 'NN'),
#  ('food', 'NN'),
#  ('game', 'NN'),
#  ('health', 'NN'),
#  ('hr', 'NN'),
#  ('marketing', 'NN'),
#  ('news', 'NN'),
#  ('personal', 'JJ'),
#  ('productivity', 'NN'),
#  ('shopping', 'VBG'),
#  ('social', 'JJ'),
#  ('sport', 'NN'),
#  ('travel', 'NN'),
#  ('utility', 'NN'),
#  ('background', 'IN'),
#  ('1950', 'CD'),
#  ('alan', 'NN'),
#  ('turing', 'VBG'),
#  ('famous', 'JJ'),
#  ('article', 'NN'),
#  ('computing', 'VBG'),
#  ('machinery', 'NN'),
#  ('intelligence', 'NN'),
#  ('published', 'VBN'),
#  ('proposed', 'VBN'),
#  ('called', 'VBN'),
#  ('turing', 'VBG'),
#  ('test', 'NN'),
#  ('criterion', 'NN'),
#  ('intelligence', 'NN'),
#  ('criterion', 'NN'),
#  ('depends', 'VBZ'),
#  ('ability', 'NN'),
#  ('computer', 'NN'),
#  ('program', 'NN'),
#  ('impersonate', 'NN'),
#  ('human', 'JJ'),
#  ('realtime', 'NN'),
#  ('written', 'VBN'),
#  ('conversation', 'NN'),
#  ('human', 'JJ'),
#  ('judge', 'NN'),
#  ('sufficiently', 'RB'),
#  ('well', 'RB'),
#  ('judge', 'NN'),
#  ('unable', 'JJ'),
#  ('distinguish', 'JJ'),
#  ('reliablyon', 'NN'),
#  ('basis', 'NN'),
#  ('conversational', 'JJ'),
#  ('content', 'NN'),
#  ('alonebetween', 'JJ'),
#  ('program', 'NN'),
#  ('real', 'JJ'),
#  ('human', 'JJ'),
#  ('notoriety', 'NN'),
#  ('turing', 'VBG'),
#  ('proposed', 'VBN'),
#  ('test', 'NN'),
#  ('stimulated', 'VBN'),
#  ('great', 'JJ'),
#  ('interest', 'NN'),
#  ('joseph', 'NN'),
#  ('weizenbaum', 'JJ'),
#  ('program', 'NN'),
#  ('eliza', 'NN'),
#  ('published', 'VBN'),
#  ('1966', 'CD'),
#  ('seemed', 'VBD'),
#  ('able', 'JJ'),
#  ('fool', 'NN'),
#  ('user', 'NN'),
#  ('believing', 'VBG'),
#  ('conversing', 'VBG'),
#  ('real', 'JJ'),
#  ('human', 'JJ'),
#  ('however', 'RB'),
#  ('weizenbaum', 'VBP'),
#  ('claim', 'NN'),
#  ('eliza', 'NN'),
#  ('genuinely', 'RB'),
#  ('intelligent', 'JJ'),
#  ('introduction', 'NN'),
#  ('paper', 'NN'),
#  ('presented', 'VBD'),
#  ('debunking', 'VBG'),
#  ('exercise', 'NN'),
#  ('artificial', 'JJ'),
#  ('intelligence', 'NN'),
#  ('machine', 'NN'),
#  ('made', 'VBN'),
#  ('behave', 'VBP'),
#  ('wondrous', 'JJ'),
#  ('way', 'NN'),
#  ('often', 'RB'),
#  ('sufficient', 'JJ'),
#  ('dazzle', 'NNS'),
#  ('even', 'RB'),
#  ('experienced', 'VBD'),
#  ('observer', 'RP'),
#  ('particular', 'JJ'),
#  ('program', 'NN'),
#  ('unmasked', 'JJ'),
#  ('inner', 'NN'),
#  ('working', 'VBG'),
#  ('explained', 'VBD'),
#  ('magic', 'JJ'),
#  ('crumbles', 'NNS'),
#  ('away', 'RB'),
#  ('stand', 'VBP'),
#  ('revealed', 'VBN'),
#  ('mere', 'JJ'),
#  ('collection', 'NN'),
#  ('procedure', 'NN'),
#  ('observer', 'IN'),
#  ('say', 'NN'),
#  ('could', 'MD'),
#  ('written', 'VBN'),
#  ('thought', 'JJ'),
#  ('move', 'NN'),
#  ('program', 'NN'),
#  ('question', 'NN'),
#  ('shelf', 'NN'),
#  ('marked', 'VBD'),
#  ('intelligent', 'JJ'),
#  ('reserved', 'VBN'),
#  ('curio', 'NN'),
#  ('object', 'JJ'),
#  ('paper', 'NN'),
#  ('cause', 'NN'),
#  ('reevaluation', 'NN'),
#  ('program', 'NN'),
#  ('explained', 'VBN'),
#  ('program', 'NN'),
#  ('ever', 'RB'),
#  ('needed', 'VBD'),
#  ('eliza', 'JJ'),
#  ('key', 'JJ'),
#  ('method', 'NN'),
#  ('operation', 'NN'),
#  ('copied', 'VBD'),
#  ('chatbot', 'NN'),
#  ('designer', 'NN'),
#  ('ever', 'RB'),
#  ('since', 'IN'),
#  ('involves', 'NNS'),
#  ('recognition', 'VBP'),
#  ('cue', 'NN'),
#  ('word', 'NN'),
#  ('phrase', 'NN'),
#  ('input', 'NN'),
#  ('output', 'NN'),
#  ('corresponding', 'VBG'),
#  ('preprepared', 'VBD'),
#  ('preprogrammed', 'VBN'),
#  ('response', 'NN'),
#  ('move', 'NN'),
#  ('conversation', 'NN'),
#  ('forward', 'RB'),
#  ('apparently', 'RB'),
#  ('meaningful', 'JJ'),
#  ('way', 'NN'),
#  ('eg', 'IN'),
#  ('responding', 'VBG'),
#  ('input', 'NN'),
#  ('contains', 'NNS'),
#  ('word', 'NN'),
#  ('mother', 'NN'),
#  ('tell', 'VBP'),
#  ('family', 'NN'),
#  ('thus', 'RB'),
#  ('illusion', 'NN'),
#  ('understanding', 'NN'),
#  ('generated', 'VBD'),
#  ('even', 'RB'),
#  ('though', 'IN'),
#  ('processing', 'VBG'),
#  ('involved', 'VBN'),
#  ('merely', 'RB'),
#  ('superficial', 'JJ'),
#  ('eliza', 'NN'),
#  ('showed', 'VBD'),
#  ('illusion', 'NN'),
#  ('surprisingly', 'RB'),
#  ('easy', 'JJ'),
#  ('generate', 'NN'),
#  ('human', 'JJ'),
#  ('judge', 'NN'),
#  ('ready', 'JJ'),
#  ('give', 'JJ'),
#  ('benefit', 'NN'),
#  ('doubt', 'NN'),
#  ('conversational', 'JJ'),
#  ('response', 'NN'),
#  ('capable', 'JJ'),
#  ('interpreted', 'JJ'),
#  ('intelligent', 'JJ'),
#  ('interface', 'NN'),
#  ('designer', 'NN'),
#  ('come', 'VBP'),
#  ('appreciate', 'NN'),
#  ('human', 'JJ'),
#  ('readiness', 'NN'),
#  ('interpret', 'NN'),
#  ('computer', 'NN'),
#  ('output', 'NN'),
#  ('genuinely', 'RB'),
#  ('conversationaleven', 'VBN'),
#  ('actually', 'RB'),
#  ('based', 'VBN'),
#  ('rather', 'RB'),
#  ('simple', 'JJ'),
#  ('patternmatchingcan', 'JJ'),
#  ('exploited', 'VBN'),
#  ('useful', 'JJ'),
#  ('purpose', 'JJ'),
#  ('people', 'NNS'),
#  ('prefer', 'VBP'),
#  ('engage', 'JJ'),
#  ('program', 'NN'),
#  ('humanlike', 'NN'),
#  ('give', 'VBP'),
#  ('chatbotstyle', 'NN'),
#  ('technique', 'NN'),
#  ('potentially', 'RB'),
#  ('useful', 'JJ'),
#  ('role', 'NN'),
#  ('interactive', 'NN'),
#  ('system', 'NN'),
#  ('need', 'VBP'),
#  ('elicit', 'JJ'),
#  ('information', 'NN'),
#  ('user', 'NN'),
#  ('long', 'JJ'),
#  ('information', 'NN'),
#  ('relatively', 'RB'),
#  ('straightforward', 'JJ'),
#  ('fall', 'NN'),
#  ('predictable', 'JJ'),
#  ('category', 'NN'),
#  ('thus', 'RB'),
#  ('example', 'NN'),
#  ('online', 'NN'),
#  ('help', 'NN'),
#  ('system', 'NN'),
#  ('usefully', 'RB'),
#  ('employ', 'VBZ'),
#  ('chatbot', 'NN'),
#  ('technique', 'NN'),
#  ('identify', 'VB'),
#  ('area', 'NN'),
#  ('help', 'NN'),
#  ('user', 'VB'),
#  ('require', 'VB'),
#  ('potentially', 'RB'),
#  ('providing', 'VBG'),
#  ('friendlier', 'JJR'),
#  ('interface', 'NN'),
#  ('formal', 'JJ'),
#  ('search', 'NN'),
#  ('menu', 'NN'),
#  ('system', 'NN'),
#  ('sort', 'NN'),
#  ('usage', 'NN'),
#  ('hold', 'NN'),
#  ('prospect', 'NN'),
#  ('moving', 'VBG'),
#  ('chatbot', 'NN'),
#  ('technology', 'NN'),
#  ('weizenbaum', 'VBZ'),
#  ('shelf', 'PRP'),
#  ('reserved', 'VBD'),
#  ('curio', 'NN'),
#  ('marked', 'VBN'),
#  ('genuinely', 'RB'),
#  ('useful', 'JJ'),
#  ('computational', 'JJ'),
#  ('method', 'NN'),
#  ('development', 'NN'),
#  ('classic', 'JJ'),
#  ('historic', 'JJ'),
#  ('early', 'JJ'),
#  ('chatbots', 'NNS'),
#  ('eliza', 'IN'),
#  ('1966', 'CD'),
#  ('parry', 'NN'),
#  ('1972', 'CD'),
#  ('recent', 'JJ'),
#  ('notable', 'JJ'),
#  ('program', 'NN'),
#  ('include', 'VBP'),
#  ('alice', 'JJ'),
#  ('jabberwacky', 'JJ'),
#  ('dude', 'NN'),
#  ('agence', 'NN'),
#  ('nationale', 'FW'),
#  ('de', 'FW'),
#  ('la', 'FW'),
#  ('recherche', 'FW'),
#  ('cnrs', 'NN'),
#  ('2006', 'CD'),
#  ('eliza', 'NN'),
#  ('parry', 'NN'),
#  ('used', 'VBN'),
#  ('exclusively', 'RB'),
#  ('simulate', 'JJ'),
#  ('typed', 'VBD'),
#  ('conversation', 'NN'),
#  ('many', 'JJ'),
#  ('chatbots', 'NNS'),
#  ('include', 'VBP'),
#  ('functional', 'JJ'),
#  ('feature', 'NN'),
#  ('game', 'NN'),
#  ('web', 'NN'),
#  ('searching', 'VBG'),
#  ('ability', 'NN'),
#  ('1984', 'CD'),
#  ('book', 'NN'),
#  ('called', 'VBN'),
#  ('policeman', 'JJ'),
#  ('beard', 'NN'),
#  ('half', 'NN'),
#  ('constructed', 'VBD'),
#  ('published', 'VBN'),
#  ('allegedly', 'RB'),
#  ('written', 'VBN'),
#  ('chatbot', 'JJ'),
#  ('racter', 'NN'),
#  ('though', 'IN'),
#  ('program', 'NN'),
#  ('released', 'VBN'),
#  ('would', 'MD'),
#  ('capable', 'VB'),
#  ('one', 'CD'),
#  ('pertinent', 'NN'),
#  ('field', 'NN'),
#  ('ai', 'VBP'),
#  ('research', 'NN'),
#  ('natural', 'JJ'),
#  ('language', 'NN'),
#  ('processing', 'NN'),
#  ('usually', 'RB'),
#  ('weak', 'JJ'),
#  ('ai', 'JJ'),
#  ('field', 'NN'),
#  ('employ', 'NN'),
#  ('specialized', 'VBD'),
#  ('software', 'NN'),
#  ('programming', 'VBG'),
#  ('language', 'NN'),
#  ('created', 'VBD'),
#  ('specifically', 'RB'),
#  ('narrow', 'JJ'),
#  ('function', 'NN'),
#  ('required', 'VBN'),
#  ('example', 'NN'),
#  ('alice', 'NN'),
#  ('us', 'PRP'),
#  ('markup', 'JJ'),
#  ('language', 'NN'),
#  ('called', 'VBN'),
#  ('aiml', 'RB'),
#  ('specific', 'JJ'),
#  ('function', 'NN'),
#  ('conversational', 'JJ'),
#  ('agent', 'NN'),
#  ('since', 'IN'),
#  ('adopted', 'VBN'),
#  ('various', 'JJ'),
#  ('developer', 'NN'),
#  ('called', 'VBN'),
#  ('alicebots', 'NNS'),
#  ('nevertheless', 'RB'),
#  ('alice', 'RB'),
#  ('still', 'RB'),
#  ('purely', 'RB'),
#  ('based', 'VBN'),
#  ('pattern', 'NN'),
#  ('matching', 'VBG'),
#  ('technique', 'NN'),
#  ('without', 'IN'),
#  ('reasoning', 'VBG'),
#  ('capability', 'NN'),
#  ('technique', 'NN'),
#  ('eliza', 'NN'),
#  ('using', 'VBG'),
#  ('back', 'RB'),
#  ('1966', 'CD'),
#  ('strong', 'JJ'),
#  ('ai', 'NN'),
#  ('would', 'MD'),
#  ('require', 'VB'),
#  ('sapience', 'NN'),
#  ('logical', 'JJ'),
#  ('reasoning', 'VBG'),
#  ('ability', 'NN'),
#  ('jabberwacky', 'NN'),
#  ('learns', 'VBZ'),
#  ('new', 'JJ'),
#  ('response', 'NN'),
#  ('context', 'NN'),
#  ('based', 'VBN'),
#  ('realtime', 'RB'),
#  ('user', 'JJ'),
#  ('interaction', 'NN'),
#  ('rather', 'RB'),
#  ('driven', 'RB'),
#  ('static', 'JJ'),
#  ('database', 'NN'),
#  ('recent', 'JJ'),
#  ('chatbots', 'NNS'),
#  ('also', 'RB'),
#  ('combine', 'VBP'),
#  ('realtime', 'NN'),
#  ('learning', 'VBG'),
#  ('evolutionary', 'JJ'),
#  ('algorithm', 'NNS'),
#  ('optimise', 'VBP'),
#  ('ability', 'NN'),
#  ('communicate', 'NN'),
#  ('based', 'VBN'),
#  ('conversation', 'NN'),
#  ('held', 'VBN'),
#  ('still', 'RB'),
#  ('currently', 'RB'),
#  ('general', 'JJ'),
#  ('purpose', 'JJ'),
#  ('conversational', 'JJ'),
#  ('artificial', 'JJ'),
#  ('intelligence', 'NN'),
#  ('software', 'NN'),
#  ('developer', 'NN'),
#  ('focus', 'NN'),
#  ('practical', 'JJ'),
#  ('aspect', 'NN'),
#  ('information', 'NN'),
#  ('retrieval', 'NN'),
#  ('chatbot', 'NN'),
#  ('competition', 'NN'),
#  ('focus', 'NN'),
#  ('turing', 'VBG'),
#  ('test', 'NN'),
#  ('specific', 'JJ'),
#  ('goal', 'NN'),
#  ('two', 'CD'),
#  ('annual', 'JJ'),
#  ('contest', 'NN'),
#  ('loebner', 'NN'),
#  ('prize', 'VB'),
#  ('chatterbox', 'NN'),
#  ('challenge', 'NN'),
#  ('offline', 'NN'),
#  ('since', 'IN'),
#  ('2015', 'CD'),
#  ('material', 'NN'),
#  ('still', 'RB'),
#  ('found', 'VBD'),
#  ('web', 'RB'),
#  ('archive', 'JJ'),
#  ('according', 'VBG'),
#  ('forrester', 'NN'),
#  ('2015', 'CD'),
#  ('ai', 'NN'),
#  ('replace', 'VB'),
#  ('16', 'CD'),
#  ('percent', 'JJ'),
#  ('american', 'JJ'),
#  ('job', 'NN'),
#  ('end', 'NN'),
#  ('decadechatbots', 'NNS'),
#  ('used', 'VBN'),
#  ('application', 'NN'),
#  ('customer', 'NN'),
#  ('service', 'NN'),
#  ('sale', 'NN'),
#  ('product', 'NN'),
#  ('education', 'NN'),
#  ('however', 'RB'),
#  ('study', 'RB'),
#  ('conducted', 'VBN'),
#  ('narrative', 'JJ'),
#  ('science', 'NN'),
#  ('2015', 'CD'),
#  ('found', 'VBD'),
#  ('80', 'CD'),
#  ('percent', 'NN'),
#  ('respondent', 'NN'),
#  ('believe', 'VBP'),
#  ('ai', 'NN'),
#  ('improves', 'VBZ'),
#  ('worker', 'JJR'),
#  ('performance', 'NN'),
#  ('creates', 'NNS'),
#  ('job', 'NN'),
#  ('citation', 'NN'),
#  ('needed', 'VBN'),
#  ('application', 'NN'),
#  ('see', 'NN'),
#  ('also', 'RB'),
#  ('virtual', 'JJ'),
#  ('assistant', 'NN'),
#  ('aeromexico', 'NN'),
#  ('airline', 'NN'),
#  ('chatbot', 'NN'),
#  ('running', 'VBG'),
#  ('facebook', 'NN'),
#  ('messenger', 'NN'),
#  ('march', 'NN'),
#  ('2018', 'CD'),
#  ('messaging', 'VBG'),
#  ('apps', 'VBD'),
#  ('many', 'JJ'),
#  ('company', 'NN'),
#  ('chatbots', 'NNS'),
#  ('run', 'VBP'),
#  ('messaging', 'VBG'),
#  ('apps', 'NN'),
#  ('like', 'IN'),
#  ('facebook', 'NN'),
#  ('messenger', 'NN'),
#  ('since', 'IN'),
#  ('2016', 'CD'),
#  ('wechat', 'IN'),
#  ('since', 'IN'),
#  ('2013', 'CD'),
#  ('whatsapp', 'NN'),
#  ('livechat', 'WP'),
#  ('kik', 'VBZ'),
#  ('slack', 'NN'),
#  ('line', 'NN'),
#  ('telegram', 'NN'),
#  ('simply', 'RB'),
#  ('via', 'IN'),
#  ('sm', 'NN'),
#  ('used', 'VBN'),
#  ('b2c', 'RB'),
#  ('customer', 'NN'),
#  ('service', 'NN'),
#  ('sale', 'NN'),
#  ('marketing', 'NN'),
#  ('2016', 'CD'),
#  ('facebook', 'NN'),
#  ('messenger', 'NN'),
#  ('allowed', 'VBN'),
#  ('developer', 'JJ'),
#  ('place', 'NN'),
#  ('chatbots', 'NNS'),
#  ('platform', 'VBP'),
#  ('30000', 'CD'),
#  ('bot', 'NN'),
#  ('created', 'VBD'),
#  ('messenger', 'JJR'),
#  ('first', 'JJ'),
#  ('six', 'CD'),
#  ('month', 'NN'),
#  ('rising', 'VBG'),
#  ('100000', 'CD'),
#  ('september', 'JJ'),
#  ('2017', 'CD'),
#  ('since', 'IN'),
#  ('september', 'NN'),
#  ('2017', 'CD'),
#  ('also', 'RB'),
#  ('part', 'NN'),
#  ('pilot', 'NN'),
#  ('program', 'NN'),
#  ('whatsapp', 'JJ'),
#  ('airline', 'NN'),
#  ('klm', 'NN'),
#  ('aeromxico', 'NN'),
#  ('announced', 'VBD'),
#  ('participation', 'NN'),
#  ('testing', 'VBG'),
#  ('airline', 'NN'),
#  ('previously', 'RB'),
#  ('launched', 'VBN'),
#  ('customer', 'NN'),
#  ('service', 'NN'),
#  ('facebook', 'NN'),
#  ('messenger', 'NN'),
#  ('platform', 'NN'),
#  ('bot', 'NN'),
#  ('usually', 'RB'),
#  ('appear', 'VBP'),
#  ('one', 'CD'),
#  ('user', 'NN'),
#  ('contact', 'NN'),
#  ('sometimes', 'RB'),
#  ('act', 'JJ'),
#  ('participant', 'JJ'),
#  ('group', 'NN'),
#  ('chat', 'VBD'),
#  ('many', 'JJ'),
#  ('bank', 'NN'),
#  ('insurer', 'NN'),
#  ('medium', 'NN'),
#  ('ecommerce', 'NN'),
#  ('company', 'NN'),
#  ('airline', 'NN'),
#  ('hotel', 'NN'),
#  ('chain', 'NN'),
#  ('retailer', 'NN'),
#  ('health', 'NN'),
#  ('care', 'NN'),
#  ('provider', 'NN'),
#  ('government', 'NN'),
#  ('entity', 'NN'),
#  ('restaurant', 'NN'),
#  ('chain', 'NN'),
#  ('used', 'VBD'),
#  ('chatbots', 'NNS'),
#  ('answer', 'RB'),
#  ('simple', 'JJ'),
#  ('question', 'NN'),
#  ('increase', 'NN'),
#  ('customer', 'NN'),
#  ('engagement', 'JJ'),
#  ('promotion', 'NN'),
#  ('offer', 'VBP'),
#  ('additional', 'JJ'),
#  ('way', 'NN'),
#  ('order', 'NN'),
#  ('2017', 'CD'),
#  ('study', 'NN'),
#  ('showed', 'VBD'),
#  ('4', 'CD'),
#  ('company', 'NN'),
#  ('used', 'VBN'),
#  ('chatbotsaccording', 'NN'),
#  ('2016', 'CD'),
#  ('study', 'NN'),
#  ('80', 'CD'),
#  ('business', 'NN'),
#  ('said', 'VBD'),
#  ('intended', 'VBN'),
#  ('one', 'CD'),
#  ('2020', 'CD'),
#  ('part', 'NN'),
#  ('company', 'NN'),
#  ('apps', 'VBZ'),
#  ('website', 'RB'),
#  ('previous', 'JJ'),
#  ('generation', 'NN'),
#  ('chatbots', 'NNS'),
#  ('present', 'JJ'),
#  ('company', 'NN'),
#  ('website', 'NN'),
#  ('eg', 'NN'),
#  ('ask', 'NN'),
#  ('jenn', 'NN'),
#  ('alaska', 'JJ'),
#  ('airline', 'NN'),
#  ('debuted', 'VBD'),
#  ('2008', 'CD'),
#  ('expedia', 'NN'),
#  ('virtual', 'JJ'),
#  ('customer', 'NN'),
#  ('service', 'NN'),
#  ('agent', 'NN'),
#  ('launched', 'VBD'),
#  ('2011the', 'CD'),
#  ('newer', 'JJR'),
#  ('generation', 'NN'),
#  ('chatbots', 'NNS'),
#  ('includes', 'VBZ'),
#  ('ibm', 'NN'),
#  ('watsonpowered', 'VBD'),
#  ('rocky', 'NN'),
#  ('introduced', 'VBN'),
#  ('february', 'JJ'),
#  ('2017', 'CD'),
#  ('new', 'JJ'),
#  ('york', 'NN'),
#  ('citybased', 'VBD'),
#  ('ecommerce', 'JJ'),
#  ('company', 'NN'),
#  ('rare', 'JJ'),
#  ('carat', 'NN'),
#  ('provide', 'VBP'),
#  ('information', 'NN'),
#  ('prospective', 'JJ'),
#  ('diamond', 'NN'),
#  ('buyer', 'NN'),
#  ('company', 'NN'),
#  ('internal', 'JJ'),
#  ('platform', 'NN'),
#  ('company', 'NN'),
#  ('explore', 'VB'),
#  ('way', 'NN'),
#  ('use', 'IN'),
#  ('chatbots', 'NNS'),
#  ('internally', 'RB'),
#  ('example', 'NN'),
#  ('customer', 'NN'),
#  ('support', 'NN'),
#  ('human', 'JJ'),
#  ('resource', 'NN'),
#  ('even', 'RB'),
#  ('internetofthings', 'NNS'),
#  ('iot', 'VBP'),
#  ('project', 'NN'),
#  ('overstockcom', 'IN'),
#  ('one', 'CD'),
#  ('reportedly', 'RB'),
#  ('launched', 'VBD'),
#  ('chatbot', 'NN'),
#  ('named', 'VBN'),
#  ('mila', 'JJ'),
#  ('automate', 'NN'),
#  ('certain', 'JJ'),
#  ('simple', 'JJ'),
#  ('yet', 'RB'),
#  ('timeconsuming', 'VBG'),
#  ('process', 'NN'),
#  ('requesting', 'VBG'),
#  ('sick', 'JJ'),
#  ('leaveother', 'NN'),
#  ('large', 'JJ'),
#  ('company', 'NN'),
#  ('lloyd', 'VBD'),
#  ('banking', 'VBG'),
#  ('group', 'NN'),
#  ('royal', 'VBD'),
#  ('bank', 'NN'),
#  ('scotland', 'NN'),
#  ('renault', 'NN'),
#  ('citron', 'NN'),
#  ('using', 'VBG'),
#  ('automated', 'VBN'),
#  ('online', 'JJ'),
#  ('assistant', 'NN'),
#  ('instead', 'RB'),
#  ('call', 'VB'),
#  ('centre', 'JJ'),
#  ('human', 'JJ'),
#  ('provide', 'NN'),
#  ('first', 'RB'),
#  ('point', 'VB'),
#  ('contact', 'NN'),
#  ('saas', 'JJ'),
#  ('chatbot', 'NN'),
#  ('business', 'NN'),
#  ('ecosystem', 'VBD'),
#  ('steadily', 'RB'),
#  ('growing', 'VBG'),
#  ('since', 'IN'),
#  ('f8', 'NN'),
#  ('conference', 'NN'),
#  ('zuckerberg', 'NN'),
#  ('unveiled', 'JJ'),
#  ('messenger', 'NN'),
#  ('would', 'MD'),
#  ('allow', 'VB'),
#  ('chatbots', 'NNS'),
#  ('app', 'JJ'),
#  ('toy', 'JJ'),
#  ('chatbots', 'NNS'),
#  ('also', 'RB'),
#  ('incorporated', 'VBN'),
#  ('device', 'NN'),
#  ('primarily', 'RB'),
#  ('meant', 'VBD'),
#  ('computing', 'VBG'),
#  ('toy', 'NN'),
#  ('hello', 'NN'),
#  ('barbie', 'NN'),
#  ('internetconnected', 'VBN'),
#  ('version', 'NN'),
#  ('doll', 'NN'),
#  ('us', 'PRP'),
#  ('chatbot', 'VBP'),
#  ('provided', 'VBN'),
#  ('company', 'NN'),
#  ('toytalk', 'NN'),
#  ('previously', 'RB'),
#  ('used', 'VBN'),
#  ('chatbot', 'NN'),
#  ('range', 'NN'),
#  ('smartphonebased', 'VBD'),
#  ('character', 'JJR'),
#  ('childrenthese', 'JJ'),
#  ('character', 'NN'),
#  ('behavior', 'NN'),
#  ('constrained', 'VBN'),
#  ('set', 'VBN'),
#  ('rule', 'NN'),
#  ('effect', 'NN'),
#  ('emulate', 'NN'),
#  ('particular', 'JJ'),
#  ('character', 'NN'),
#  ('produce', 'VBP'),
#  ('storyline', 'JJ'),
#  ('ibm', 'NN'),
#  ('watson', 'NN'),
#  ('computer', 'NN'),
#  ('used', 'VBN'),
#  ('basis', 'NN'),
#  ('chatbotbased', 'VBD'),
#  ('educational', 'JJ'),
#  ('toy', 'NN'),
#  ('company', 'NN'),
#  ('cognitoys', 'VBZ'),
#  ('intended', 'VBN'),
#  ('interact', 'JJ'),
#  ('child', 'JJ'),
#  ('educational', 'JJ'),
#  ('purpose', 'NN'),
#  ('chatbot', 'JJ'),
#  ('creation', 'NN'),
#  ('process', 'NN'),
#  ('creating', 'VBG'),
#  ('chatbot', 'NN'),
#  ('follows', 'VBZ'),
#  ('pattern', 'JJ'),
#  ('similar', 'JJ'),
#  ('development', 'NN'),
#  ('web', 'NN'),
#  ('page', 'NN'),
#  ('mobile', 'JJ'),
#  ('app', 'NN'),
#  ('divided', 'VBD'),
#  ('design', 'NN'),
#  ('building', 'NN'),
#  ('analytics', 'NNS'),
#  ('maintenance', 'NN'),
#  ('design', 'NN'),
#  ('chatbot', 'NN'),
#  ('design', 'NN'),
#  ('process', 'NN'),
#  ('defines', 'VBZ'),
#  ('interaction', 'NN'),
#  ('user', 'IN'),
#  ('chatbotthe', 'NN'),
#  ('chatbot', 'NN'),
#  ('designer', 'NN'),
#  ('define', 'NN'),
#  ('chatbot', 'NN'),
#  ('personality', 'NN'),
#  ('question', 'NN'),
#  ('asked', 'VBD'),
#  ('user', 'JJ'),
#  ('overall', 'JJ'),
#  ('interactionit', 'NN'),
#  ('viewed', 'VBD'),
#  ('subset', 'JJ'),
#  ('conversational', 'JJ'),
#  ('design', 'NN'),
#  ('order', 'NN'),
#  ('speed', 'NN'),
#  ('process', 'NN'),
#  ('designer', 'NN'),
#  ('use', 'NN'),
#  ('dedicated', 'VBN'),
#  ('chatbot', 'JJ'),
#  ('design', 'NN'),
#  ('tool', 'NN'),
#  ('allow', 'VBP'),
#  ('immediate', 'JJ'),
#  ('preview', 'NN'),
#  ('team', 'NN'),
#  ('collaboration', 'NN'),
#  ('video', 'NN'),
#  ('exportan', 'NN'),
#  ('important', 'JJ'),
#  ('part', 'NN'),
#  ('chatbot', 'NN'),
#  ('design', 'NN'),
#  ('also', 'RB'),
#  ('centered', 'VBD'),
#  ('around', 'IN'),
#  ('user', 'JJ'),
#  ('testing', 'VBG'),
#  ('user', 'NN'),
#  ('testing', 'VBG'),
#  ...]

# %% [markdown]
# CHUNKING
# It basically means picking up individual pieces of information and grouping them into bigger pieces.
# Chunking is a process that requires POS tagged input, and it provides chunks of phrases as output. Similar to POS tags, there is a standard set of chunk tags like Noun Phrase (NP), Verb Phrase (VP), etc.

# %%
chunkGram = "NP: {<DT>?<JJ>*<NN>}"
chunkParser = nltk.RegexpParser(chunkGram)
chunked = chunkParser.parse(pos_data)

print(chunked)
# Out:
# (S
#   (NP chatbot/NN)
#   also/RB
#   known/VBN
#   (NP talkbot/NN)
#   (NP chatterbot/NN)
#   (NP bot/NN)
#   (NP im/NN)
#   (NP bot/NN)
#   (NP interactive/JJ agent/NN)
#   (NP artificial/JJ conversational/JJ entity/NN)
#   (NP computer/NN)
#   (NP program/NN)
#   (NP artificial/JJ intelligence/NN)
#   (NP conduct/NN)
#   (NP conversation/NN)
#   via/IN
#   (NP auditory/JJ textual/JJ method/NN)
#   (NP program/NN)
#   often/RB
#   designed/VBN
#   convincingly/RB
#   (NP simulate/JJ human/NN)
#   would/MD
#   behave/VB
#   (NP conversational/JJ partner/NN)
#   thereby/RB
#   passing/VBG
#   turing/VBG
#   (NP test/NN)
#   chatbots/NNS
#   typically/RB
#   used/VBN
#   (NP dialog/NN)
#   (NP system/NN)
#   (NP various/JJ practical/JJ purpose/NN)
#   including/VBG
#   (NP customer/NN)
#   (NP service/NN)
#   (NP information/NN)
#   (NP acquisition/NN)
#   chatterbots/NNS
#   use/VBP
#   (NP sophisticated/JJ natural/JJ language/NN)
#   (NP processing/NN)
#   (NP system/NN)
#   (NP many/JJ simpler/NN)
#   (NP system/NN)
#   scan/JJ
#   keywords/NNS
#   within/IN
#   (NP input/NN)
#   pull/VBP
#   (NP reply/NN)
#   matching/JJ
#   keywords/NNS
#   similar/JJ
#   wording/VBG
#   (NP pattern/JJ database/JJ term/NN)
#   (NP chatterbot/NN)
#   originally/RB
#   coined/VBD
#   (NP michael/JJ mauldin/NN)
#   (NP creator/NN)
#   first/RB
#   verbot/VBZ
#   (NP julia/NN)
#   1994/CD
#   (NP describe/NN)
#   (NP conversational/JJ programstoday/NN)
#   chatbots/NNS
#   either/CC
#   accessed/JJ
#   via/IN
#   (NP virtual/JJ assistant/NN)
#   (NP google/NN)
#   (NP assistant/NN)
#   (NP amazon/NN)
#   (NP alexa/NN)
#   via/IN
#   messaging/VBG
#   (NP apps/JJ facebook/NN)
#   (NP messenger/NN)
#   wechat/WP
#   via/IN
#   (NP individual/JJ organization/NN)
#   apps/IN
#   website/JJ
#   chatbots/NNS
#   classified/VBN
#   (NP usage/JJ category/JJ conversational/JJ commerce/NN)
#   (NP ecommerce/NN)
#   via/IN
#   chat/WP
#   analytics/NNS
#   (NP communication/NN)
#   (NP customer/NN)
#   (NP support/NN)
#   (NP design/NN)
#   (NP developer/NN)
#   (NP tool/NN)
#   (NP education/NN)
#   (NP entertainment/NN)
#   (NP finance/NN)
#   (NP food/NN)
#   (NP game/NN)
#   (NP health/NN)
#   (NP hr/NN)
#   (NP marketing/NN)
#   (NP news/NN)
#   (NP personal/JJ productivity/NN)
#   shopping/VBG
#   (NP social/JJ sport/NN)
#   (NP travel/NN)
#   (NP utility/NN)
#   background/IN
#   1950/CD
#   (NP alan/NN)
#   turing/VBG
#   (NP famous/JJ article/NN)
#   computing/VBG
#   (NP machinery/NN)
#   (NP intelligence/NN)
#   published/VBN
#   proposed/VBN
#   called/VBN
#   turing/VBG
#   (NP test/NN)
#   (NP criterion/NN)
#   (NP intelligence/NN)
#   (NP criterion/NN)
#   depends/VBZ
#   (NP ability/NN)
#   (NP computer/NN)
#   (NP program/NN)
#   (NP impersonate/NN)
#   (NP human/JJ realtime/NN)
#   written/VBN
#   (NP conversation/NN)
#   (NP human/JJ judge/NN)
#   sufficiently/RB
#   well/RB
#   (NP judge/NN)
#   (NP unable/JJ distinguish/JJ reliablyon/NN)
#   (NP basis/NN)
#   (NP conversational/JJ content/NN)
#   (NP alonebetween/JJ program/NN)
#   (NP real/JJ human/JJ notoriety/NN)
#   turing/VBG
#   proposed/VBN
#   (NP test/NN)
#   stimulated/VBN
#   (NP great/JJ interest/NN)
#   (NP joseph/NN)
#   (NP weizenbaum/JJ program/NN)
#   (NP eliza/NN)
#   published/VBN
#   1966/CD
#   seemed/VBD
#   (NP able/JJ fool/NN)
#   (NP user/NN)
#   believing/VBG
#   conversing/VBG
#   real/JJ
#   human/JJ
#   however/RB
#   weizenbaum/VBP
#   (NP claim/NN)
#   (NP eliza/NN)
#   genuinely/RB
#   (NP intelligent/JJ introduction/NN)
#   (NP paper/NN)
#   presented/VBD
#   debunking/VBG
#   (NP exercise/NN)
#   (NP artificial/JJ intelligence/NN)
#   (NP machine/NN)
#   made/VBN
#   behave/VBP
#   (NP wondrous/JJ way/NN)
#   often/RB
#   sufficient/JJ
#   dazzle/NNS
#   even/RB
#   experienced/VBD
#   observer/RP
#   (NP particular/JJ program/NN)
#   (NP unmasked/JJ inner/NN)
#   working/VBG
#   explained/VBD
#   magic/JJ
#   crumbles/NNS
#   away/RB
#   stand/VBP
#   revealed/VBN
#   (NP mere/JJ collection/NN)
#   (NP procedure/NN)
#   observer/IN
#   (NP say/NN)
#   could/MD
#   written/VBN
#   (NP thought/JJ move/NN)
#   (NP program/NN)
#   (NP question/NN)
#   (NP shelf/NN)
#   marked/VBD
#   intelligent/JJ
#   reserved/VBN
#   (NP curio/NN)
#   (NP object/JJ paper/NN)
#   (NP cause/NN)
#   (NP reevaluation/NN)
#   (NP program/NN)
#   explained/VBN
#   (NP program/NN)
#   ever/RB
#   needed/VBD
#   (NP eliza/JJ key/JJ method/NN)
#   (NP operation/NN)
#   copied/VBD
#   (NP chatbot/NN)
#   (NP designer/NN)
#   ever/RB
#   since/IN
#   involves/NNS
#   recognition/VBP
#   (NP cue/NN)
#   (NP word/NN)
#   (NP phrase/NN)
#   (NP input/NN)
#   (NP output/NN)
#   corresponding/VBG
#   preprepared/VBD
#   preprogrammed/VBN
#   (NP response/NN)
#   (NP move/NN)
#   (NP conversation/NN)
#   forward/RB
#   apparently/RB
#   (NP meaningful/JJ way/NN)
#   eg/IN
#   responding/VBG
#   (NP input/NN)
#   contains/NNS
#   (NP word/NN)
#   (NP mother/NN)
#   tell/VBP
#   (NP family/NN)
#   thus/RB
#   (NP illusion/NN)
#   (NP understanding/NN)
#   generated/VBD
#   even/RB
#   though/IN
#   processing/VBG
#   involved/VBN
#   merely/RB
#   (NP superficial/JJ eliza/NN)
#   showed/VBD
#   (NP illusion/NN)
#   surprisingly/RB
#   (NP easy/JJ generate/NN)
#   (NP human/JJ judge/NN)
#   (NP ready/JJ give/JJ benefit/NN)
#   (NP doubt/NN)
#   (NP conversational/JJ response/NN)
#   (NP capable/JJ interpreted/JJ intelligent/JJ interface/NN)
#   (NP designer/NN)
#   come/VBP
#   (NP appreciate/NN)
#   (NP human/JJ readiness/NN)
#   (NP interpret/NN)
#   (NP computer/NN)
#   (NP output/NN)
#   genuinely/RB
#   conversationaleven/VBN
#   actually/RB
#   based/VBN
#   rather/RB
#   simple/JJ
#   patternmatchingcan/JJ
#   exploited/VBN
#   useful/JJ
#   purpose/JJ
#   people/NNS
#   prefer/VBP
#   (NP engage/JJ program/NN)
#   (NP humanlike/NN)
#   give/VBP
#   (NP chatbotstyle/NN)
#   (NP technique/NN)
#   potentially/RB
#   (NP useful/JJ role/NN)
#   (NP interactive/NN)
#   (NP system/NN)
#   need/VBP
#   (NP elicit/JJ information/NN)
#   (NP user/NN)
#   (NP long/JJ information/NN)
#   relatively/RB
#   (NP straightforward/JJ fall/NN)
#   (NP predictable/JJ category/NN)
#   thus/RB
#   (NP example/NN)
#   (NP online/NN)
#   (NP help/NN)
#   (NP system/NN)
#   usefully/RB
#   employ/VBZ
#   (NP chatbot/NN)
#   (NP technique/NN)
#   identify/VB
#   (NP area/NN)
#   (NP help/NN)
#   user/VB
#   require/VB
#   potentially/RB
#   providing/VBG
#   friendlier/JJR
#   (NP interface/NN)
#   (NP formal/JJ search/NN)
#   (NP menu/NN)
#   (NP system/NN)
#   (NP sort/NN)
#   (NP usage/NN)
#   (NP hold/NN)
#   (NP prospect/NN)
#   moving/VBG
#   (NP chatbot/NN)
#   (NP technology/NN)
#   weizenbaum/VBZ
#   shelf/PRP
#   reserved/VBD
#   (NP curio/NN)
#   marked/VBN
#   genuinely/RB
#   (NP useful/JJ computational/JJ method/NN)
#   (NP development/NN)
#   classic/JJ
#   historic/JJ
#   early/JJ
#   chatbots/NNS
#   eliza/IN
#   1966/CD
#   (NP parry/NN)
#   1972/CD
#   (NP recent/JJ notable/JJ program/NN)
#   include/VBP
#   (NP alice/JJ jabberwacky/JJ dude/NN)
#   (NP agence/NN)
#   nationale/FW
#   de/FW
#   la/FW
#   recherche/FW
#   (NP cnrs/NN)
#   2006/CD
#   (NP eliza/NN)
#   (NP parry/NN)
#   used/VBN
#   exclusively/RB
#   simulate/JJ
#   typed/VBD
#   (NP conversation/NN)
#   many/JJ
#   chatbots/NNS
#   include/VBP
#   (NP functional/JJ feature/NN)
#   (NP game/NN)
#   (NP web/NN)
#   searching/VBG
#   (NP ability/NN)
#   1984/CD
#   (NP book/NN)
#   called/VBN
#   (NP policeman/JJ beard/NN)
#   (NP half/NN)
#   constructed/VBD
#   published/VBN
#   allegedly/RB
#   written/VBN
#   (NP chatbot/JJ racter/NN)
#   though/IN
#   (NP program/NN)
#   released/VBN
#   would/MD
#   capable/VB
#   one/CD
#   (NP pertinent/NN)
#   (NP field/NN)
#   ai/VBP
#   (NP research/NN)
#   (NP natural/JJ language/NN)
#   (NP processing/NN)
#   usually/RB
#   (NP weak/JJ ai/JJ field/NN)
#   (NP employ/NN)
#   specialized/VBD
#   (NP software/NN)
#   programming/VBG
#   (NP language/NN)
#   created/VBD
#   specifically/RB
#   (NP narrow/JJ function/NN)
#   required/VBN
#   (NP example/NN)
#   (NP alice/NN)
#   us/PRP
#   (NP markup/JJ language/NN)
#   called/VBN
#   aiml/RB
#   (NP specific/JJ function/NN)
#   (NP conversational/JJ agent/NN)
#   since/IN
#   adopted/VBN
#   (NP various/JJ developer/NN)
#   called/VBN
#   alicebots/NNS
#   nevertheless/RB
#   alice/RB
#   still/RB
#   purely/RB
#   based/VBN
#   (NP pattern/NN)
#   matching/VBG
#   (NP technique/NN)
#   without/IN
#   reasoning/VBG
#   (NP capability/NN)
#   (NP technique/NN)
#   (NP eliza/NN)
#   using/VBG
#   back/RB
#   1966/CD
#   (NP strong/JJ ai/NN)
#   would/MD
#   require/VB
#   (NP sapience/NN)
#   logical/JJ
#   reasoning/VBG
#   (NP ability/NN)
#   (NP jabberwacky/NN)
#   learns/VBZ
#   (NP new/JJ response/NN)
#   (NP context/NN)
#   based/VBN
#   realtime/RB
#   (NP user/JJ interaction/NN)
#   rather/RB
#   driven/RB
#   (NP static/JJ database/NN)
#   recent/JJ
#   chatbots/NNS
#   also/RB
#   combine/VBP
#   (NP realtime/NN)
#   learning/VBG
#   evolutionary/JJ
#   algorithm/NNS
#   optimise/VBP
#   (NP ability/NN)
#   (NP communicate/NN)
#   based/VBN
#   (NP conversation/NN)
#   held/VBN
#   still/RB
#   currently/RB
#   (NP
#     general/JJ
#     purpose/JJ
#     conversational/JJ
#     artificial/JJ
#     intelligence/NN)
#   (NP software/NN)
#   (NP developer/NN)
#   (NP focus/NN)
#   (NP practical/JJ aspect/NN)
#   (NP information/NN)
#   (NP retrieval/NN)
#   (NP chatbot/NN)
#   (NP competition/NN)
#   (NP focus/NN)
#   turing/VBG
#   (NP test/NN)
#   (NP specific/JJ goal/NN)
#   two/CD
#   (NP annual/JJ contest/NN)
#   (NP loebner/NN)
#   prize/VB
#   (NP chatterbox/NN)
#   (NP challenge/NN)
#   (NP offline/NN)
#   since/IN
#   2015/CD
#   (NP material/NN)
#   still/RB
#   found/VBD
#   web/RB
#   archive/JJ
#   according/VBG
#   (NP forrester/NN)
#   2015/CD
#   (NP ai/NN)
#   replace/VB
#   16/CD
#   (NP percent/JJ american/JJ job/NN)
#   (NP end/NN)
#   decadechatbots/NNS
#   used/VBN
#   (NP application/NN)
#   (NP customer/NN)
#   (NP service/NN)
#   (NP sale/NN)
#   (NP product/NN)
#   (NP education/NN)
#   however/RB
#   study/RB
#   conducted/VBN
#   (NP narrative/JJ science/NN)
#   2015/CD
#   found/VBD
#   80/CD
#   (NP percent/NN)
#   (NP respondent/NN)
#   believe/VBP
#   (NP ai/NN)
#   improves/VBZ
#   worker/JJR
#   (NP performance/NN)
#   creates/NNS
#   (NP job/NN)
#   (NP citation/NN)
#   needed/VBN
#   (NP application/NN)
#   (NP see/NN)
#   also/RB
#   (NP virtual/JJ assistant/NN)
#   (NP aeromexico/NN)
#   (NP airline/NN)
#   (NP chatbot/NN)
#   running/VBG
#   (NP facebook/NN)
#   (NP messenger/NN)
#   (NP march/NN)
#   2018/CD
#   messaging/VBG
#   apps/VBD
#   (NP many/JJ company/NN)
#   chatbots/NNS
#   run/VBP
#   messaging/VBG
#   (NP apps/NN)
#   like/IN
#   (NP facebook/NN)
#   (NP messenger/NN)
#   since/IN
#   2016/CD
#   wechat/IN
#   since/IN
#   2013/CD
#   (NP whatsapp/NN)
#   livechat/WP
#   kik/VBZ
#   (NP slack/NN)
#   (NP line/NN)
#   (NP telegram/NN)
#   simply/RB
#   via/IN
#   (NP sm/NN)
#   used/VBN
#   b2c/RB
#   (NP customer/NN)
#   (NP service/NN)
#   (NP sale/NN)
#   (NP marketing/NN)
#   2016/CD
#   (NP facebook/NN)
#   (NP messenger/NN)
#   allowed/VBN
#   (NP developer/JJ place/NN)
#   chatbots/NNS
#   platform/VBP
#   30000/CD
#   (NP bot/NN)
#   created/VBD
#   messenger/JJR
#   first/JJ
#   six/CD
#   (NP month/NN)
#   rising/VBG
#   100000/CD
#   september/JJ
#   2017/CD
#   since/IN
#   (NP september/NN)
#   2017/CD
#   also/RB
#   (NP part/NN)
#   (NP pilot/NN)
#   (NP program/NN)
#   (NP whatsapp/JJ airline/NN)
#   (NP klm/NN)
#   (NP aeromxico/NN)
#   announced/VBD
#   (NP participation/NN)
#   testing/VBG
#   (NP airline/NN)
#   previously/RB
#   launched/VBN
#   (NP customer/NN)
#   (NP service/NN)
#   (NP facebook/NN)
#   (NP messenger/NN)
#   (NP platform/NN)
#   (NP bot/NN)
#   usually/RB
#   appear/VBP
#   one/CD
#   (NP user/NN)
#   (NP contact/NN)
#   sometimes/RB
#   (NP act/JJ participant/JJ group/NN)
#   chat/VBD
#   (NP many/JJ bank/NN)
#   (NP insurer/NN)
#   (NP medium/NN)
#   (NP ecommerce/NN)
#   (NP company/NN)
#   (NP airline/NN)
#   (NP hotel/NN)
#   (NP chain/NN)
#   (NP retailer/NN)
#   (NP health/NN)
#   (NP care/NN)
#   (NP provider/NN)
#   (NP government/NN)
#   (NP entity/NN)
#   (NP restaurant/NN)
#   (NP chain/NN)
#   used/VBD
#   chatbots/NNS
#   answer/RB
#   (NP simple/JJ question/NN)
#   (NP increase/NN)
#   (NP customer/NN)
#   (NP engagement/JJ promotion/NN)
#   offer/VBP
#   (NP additional/JJ way/NN)
#   (NP order/NN)
#   2017/CD
#   (NP study/NN)
#   showed/VBD
#   4/CD
#   (NP company/NN)
#   used/VBN
#   (NP chatbotsaccording/NN)
#   2016/CD
#   (NP study/NN)
#   80/CD
#   (NP business/NN)
#   said/VBD
#   intended/VBN
#   one/CD
#   2020/CD
#   (NP part/NN)
#   (NP company/NN)
#   apps/VBZ
#   website/RB
#   (NP previous/JJ generation/NN)
#   chatbots/NNS
#   (NP present/JJ company/NN)
#   (NP website/NN)
#   (NP eg/NN)
#   (NP ask/NN)
#   (NP jenn/NN)
#   (NP alaska/JJ airline/NN)
#   debuted/VBD
#   2008/CD
#   (NP expedia/NN)
#   (NP virtual/JJ customer/NN)
#   (NP service/NN)
#   (NP agent/NN)
#   launched/VBD
#   2011the/CD
#   newer/JJR
#   (NP generation/NN)
#   chatbots/NNS
#   includes/VBZ
#   (NP ibm/NN)
#   watsonpowered/VBD
#   (NP rocky/NN)
#   introduced/VBN
#   february/JJ
#   2017/CD
#   (NP new/JJ york/NN)
#   citybased/VBD
#   (NP ecommerce/JJ company/NN)
#   (NP rare/JJ carat/NN)
#   provide/VBP
#   (NP information/NN)
#   (NP prospective/JJ diamond/NN)
#   (NP buyer/NN)
#   (NP company/NN)
#   (NP internal/JJ platform/NN)
#   (NP company/NN)
#   explore/VB
#   (NP way/NN)
#   use/IN
#   chatbots/NNS
#   internally/RB
#   (NP example/NN)
#   (NP customer/NN)
#   (NP support/NN)
#   (NP human/JJ resource/NN)
#   even/RB
#   internetofthings/NNS
#   iot/VBP
#   (NP project/NN)
#   overstockcom/IN
#   one/CD
#   reportedly/RB
#   launched/VBD
#   (NP chatbot/NN)
#   named/VBN
#   (NP mila/JJ automate/NN)
#   certain/JJ
#   simple/JJ
#   yet/RB
#   timeconsuming/VBG
#   (NP process/NN)
#   requesting/VBG
#   (NP sick/JJ leaveother/NN)
#   (NP large/JJ company/NN)
#   lloyd/VBD
#   banking/VBG
#   (NP group/NN)
#   royal/VBD
#   (NP bank/NN)
#   (NP scotland/NN)
#   (NP renault/NN)
#   (NP citron/NN)
#   using/VBG
#   automated/VBN
#   (NP online/JJ assistant/NN)
#   instead/RB
#   call/VB
#   (NP centre/JJ human/JJ provide/NN)
#   first/RB
#   point/VB
#   (NP contact/NN)
#   (NP saas/JJ chatbot/NN)
#   (NP business/NN)
#   ecosystem/VBD
#   steadily/RB
#   growing/VBG
#   since/IN
#   (NP f8/NN)
#   (NP conference/NN)
#   (NP zuckerberg/NN)
#   (NP unveiled/JJ messenger/NN)
#   would/MD
#   allow/VB
#   chatbots/NNS
#   app/JJ
#   toy/JJ
#   chatbots/NNS
#   also/RB
#   incorporated/VBN
#   (NP device/NN)
#   primarily/RB
#   meant/VBD
#   computing/VBG
#   (NP toy/NN)
#   (NP hello/NN)
#   (NP barbie/NN)
#   internetconnected/VBN
#   (NP version/NN)
#   (NP doll/NN)
#   us/PRP
#   chatbot/VBP
#   provided/VBN
#   (NP company/NN)
#   (NP toytalk/NN)
#   previously/RB
#   used/VBN
#   (NP chatbot/NN)
#   (NP range/NN)
#   smartphonebased/VBD
#   character/JJR
#   (NP childrenthese/JJ character/NN)
#   (NP behavior/NN)
#   constrained/VBN
#   set/VBN
#   (NP rule/NN)
#   (NP effect/NN)
#   (NP emulate/NN)
#   (NP particular/JJ character/NN)
#   produce/VBP
#   (NP storyline/JJ ibm/NN)
#   (NP watson/NN)
#   (NP computer/NN)
#   used/VBN
#   (NP basis/NN)
#   chatbotbased/VBD
#   (NP educational/JJ toy/NN)
#   (NP company/NN)
#   cognitoys/VBZ
#   intended/VBN
#   (NP interact/JJ child/JJ educational/JJ purpose/NN)
#   (NP chatbot/JJ creation/NN)
#   (NP process/NN)
#   creating/VBG
#   (NP chatbot/NN)
#   follows/VBZ
#   (NP pattern/JJ similar/JJ development/NN)
#   (NP web/NN)
#   (NP page/NN)
#   (NP mobile/JJ app/NN)
#   divided/VBD
#   (NP design/NN)
#   (NP building/NN)
#   analytics/NNS
#   (NP maintenance/NN)
#   (NP design/NN)
#   (NP chatbot/NN)
#   (NP design/NN)
#   (NP process/NN)
#   defines/VBZ
#   (NP interaction/NN)
#   user/IN
#   (NP chatbotthe/NN)
#   (NP chatbot/NN)
#   (NP designer/NN)
#   (NP define/NN)
#   (NP chatbot/NN)
#   (NP personality/NN)
#   (NP question/NN)
#   asked/VBD
#   (NP user/JJ overall/JJ interactionit/NN)
#   viewed/VBD
#   (NP subset/JJ conversational/JJ design/NN)
#   (NP order/NN)
#   (NP speed/NN)
#   (NP process/NN)
#   (NP designer/NN)
#   (NP use/NN)
#   dedicated/VBN
#   (NP chatbot/JJ design/NN)
#   (NP tool/NN)
#   allow/VBP
#   (NP immediate/JJ preview/NN)
#   (NP team/NN)
#   (NP collaboration/NN)
#   (NP video/NN)
#   (NP exportan/NN)
#   (NP important/JJ part/NN)
#   (NP chatbot/NN)
#   (NP design/NN)
#   also/RB
#   centered/VBD
#   around/IN
#   user/JJ
#   testing/VBG
#   (NP user/NN)
#   testing/VBG
#   performed/VBD
#   following/VBG
#   (NP principle/NN)
#   guide/FW
#   user/IN
#   testing/VBG
#   (NP graphical/JJ interface/NN)
#   (NP building/NN)
#   (NP process/NN)
#   (NP building/NN)
#   (NP chatbot/NN)
#   divided/VBD
#   two/CD
#   (NP main/JJ task/NN)
#   understanding/VBG
#   (NP user/JJ intent/NN)
#   producing/VBG
#   (NP correct/JJ answer/NN)
#   first/RB
#   task/JJ
#   involves/NNS
#   understanding/VBG
#   (NP user/NN)
#   (NP input/NN)
#   (NP order/NN)
#   properly/RB
#   understand/VB
#   (NP user/NN)
#   (NP input/NN)
#   (NP free/JJ text/NN)
#   (NP form/NN)
#   (NP natural/JJ language/NN)
#   (NP processing/NN)
#   (NP engine/NN)
#   (NP usedthe/JJ second/JJ task/NN)
#   may/MD
#   involve/VB
#   (NP different/JJ approach/NN)
#   depending/VBG
#   (NP type/JJ response/NN)
#   (NP chatbot/NN)
#   (NP generate/NN)
#   analytics/NNS
#   (NP usage/JJ chatbot/NN)
#   monitored/VBD
#   (NP order/NN)
#   (NP spot/NN)
#   (NP potential/JJ flaw/NN)
#   (NP problem/NN)
#   also/RB
#   provide/RB
#   useful/JJ
#   insight/JJ
#   improve/VB
#   (NP final/JJ user/NN)
#   (NP experience/NN)
#   (NP maintenance/NN)
#   keep/VB
#   chatbots/NNS
#   speed/VB
#   changing/VBG
#   (NP company/NN)
#   (NP product/NN)
#   (NP service/NN)
#   (NP traditional/JJ chatbot/NN)
#   (NP development/NN)
#   (NP platform/NN)
#   require/VBP
#   (NP ongoing/JJ maintenance/NN)
#   either/CC
#   (NP form/NN)
#   (NP ongoing/JJ service/NN)
#   (NP provider/NN)
#   larger/JJR
#   (NP enterprise/NN)
#   (NP form/NN)
#   (NP inhouse/NN)
#   (NP chatbot/NN)
#   (NP training/NN)
#   (NP teamto/NN)
#   (NP eliminate/NN)
#   (NP cost/NN)
#   (NP startup/NN)
#   experimenting/VBG
#   (NP artificial/JJ intelligence/NN)
#   develop/VB
#   selflearning/VBG
#   chatbots/NNS
#   particularly/RB
#   (NP customer/NN)
#   (NP service/NN)
#   (NP application/NN)
#   (NP chatbot/NN)
#   (NP development/NN)
#   (NP platform/NN)
#   (NP process/NN)
#   building/VBG
#   testing/VBG
#   deploying/VBG
#   chatbots/NNS
#   done/VBN
#   (NP cloud/NN)
#   based/VBN
#   (NP chatbot/NN)
#   (NP development/NN)
#   (NP platform/NN)
#   offered/VBD
#   (NP cloud/JJ platform/NN)
#   (NP service/NN)
#   (NP paas/NN)
#   (NP provider/NN)
#   (NP yekaliva/NN)
#   (NP oracle/NN)
#   (NP cloud/NN)
#   (NP platform/NN)
#   (NP snatchbot/NN)
#   (NP ibm/NN)
#   (NP watsonthese/JJ cloud/NN)
#   (NP platform/NN)
#   provide/VBP
#   (NP natural/JJ language/NN)
#   processing/VBG
#   (NP artificial/JJ intelligence/NN)
#   (NP mobile/JJ backend/NN)
#   (NP service/NN)
#   (NP chatbot/NN)
#   (NP development/NN)
#   apis/RB
#   many/JJ
#   apis/VBP
#   available/JJ
#   building/VBG
#   chatbots/NNS
#   aarc/RB
#   (NP malicious/JJ use/NN)
#   malicious/JJ
#   chatbots/NNS
#   frequently/RB
#   used/VBN
#   (NP fill/NN)
#   chat/WP
#   (NP room/NN)
#   (NP spam/NN)
#   (NP advertisement/NN)
#   mimicking/VBG
#   (NP human/JJ behaviour/NN)
#   (NP conversation/NN)
#   (NP entice/NN)
#   people/NNS
#   revealing/VBG
#   (NP personal/JJ information/NN)
#   (NP bank/NN)
#   (NP account/NN)
#   (NP number/NN)
#   commonly/RB
#   found/VBD
#   yahoo/RB
#   messenger/JJR
#   (NP window/JJ live/JJ messenger/NN)
#   (NP aol/NN)
#   (NP instant/JJ messenger/NN)
#   (NP instant/JJ messaging/NN)
#   (NP protocol/NN)
#   also/RB
#   published/VBD
#   (NP report/NN)
#   (NP chatbot/NN)
#   used/VBN
#   (NP fake/JJ personal/JJ ad/NN)
#   dating/VBG
#   (NP service/NN)
#   (NP website/NN))
